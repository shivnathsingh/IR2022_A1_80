# %%
import glob
import os
import string
import nltk
import re
import pandas as pd
import numpy as np

# %%
P="/content/drive/MyDrive/Humor,Hist,Media,Food/*"

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
s=stopwords.words('english')

# %%
a=[]
for i in glob.glob(P):
  a.append("/content/drive/MyDrive/Humor,Hist,Media,Food/"+os.path.basename(i))

# %%
len(a)
# Out:
# 1133

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
from tqdm import tqdm

# %%
import os
import glob
import pandas as pd
import numpy as np
import nltk
import re
nltk.download('stopwords')
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 

import nltk
nltk.download('stopwords')  


nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import gensim
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stop_words = set(stopwords.words('english'));
p_ind={}
dict=[]
e=[]
voc=[]
docid=1
for i in tqdm(range(len(a))):
  with open(a[i],encoding="utf8",errors='ignore') as file:
    c=[]
    text =file.read()
    text=text.lower()   #to convert in to lower case 
    text=text.strip()
    text = re.sub(r'[^\w\s]', ' ', text)  # To remove puntuation
    word_tokens = word_tokenize(text)   # toknization 
    final_tokens=[w for w in word_tokens if w not in stop_words] # stopword remove
    final_tokens=[ lemmatizer.lemmatize(word) for word in final_tokens]
    final_tokens = [x for x in final_tokens if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
    final_tokens=set(final_tokens)
    for term in final_tokens:
      if term not in c:
        c.append(term)
        voc.append(term)
    dict.append(c)  
    e.append(voc)  
    counter=0
    for z in final_tokens:
      if z in p_ind:
          if docid in p_ind[z][1]:
            p_ind[z][1][docid].append(counter)
          else:
            p_ind[z][0]=p_ind[z][0]+1
            p_ind[z][1][docid]=[counter]
            counter+=1
      else:
        p_ind[z]=[]
        p_ind[z].append(1)
        p_ind[z].append({})
        p_ind[z][1][docid]=[counter]
        counter=counter+1
    docid+=1
# Out:
# 100%|██████████| 1133/1133 [00:46<00:00, 24.37it/s]

# %%
voc=list(set(voc))

# %%
counter=0
for x in range(1):
  print("")
list_pos={}
for x in range(1):
  print("")
for i in dict:
  counter+=1
  for j in i:
    if j in list_pos:
      list_pos[j].append(counter)
      for x in range(1):
        print("")
      for x in range(1):
        print("")
    else:
      list_pos[j]=[counter]
      for x in range(1):
        print("")
for x in range(1):
    print("")

# %%
import math

# %%
for x in range(1):
  print("")
idf={}                           
for i in tqdm(range(len(voc))):
  for x in range(1):
    print("")
  a=len(list_pos[voc[i]])
  b=len(dict)
  idf[voc[i]]=math.log((b/a+1),10)                      #formula given in assignment
for x in range(1):
  print("")
# Out:
# 100%|██████████| 60765/60765 [00:00<00:00, 527540.36it/s]

# %%
idf
# Out:
# {'tickle': 2.2783724736954567,
#  'confounding': 2.5782570766553374,
#  'gate': 1.3910086602379275,
#  'advantageous': 2.75396586586516,
#  'external': 1.6831221172401434,
#  'tpls': 3.0546130545568873,
#  'venerich': 3.0546130545568873,
#  'pegleg': 3.0546130545568873,
#  'miyazaki': 2.5782570766553374,
#  'untraceable': 3.0546130545568873,
#  'garaged': 3.0546130545568873,
#  'wackylanders': 3.0546130545568873,
#  'xaxian': 3.0546130545568873,
#  'authentication': 3.0546130545568873,
#  'tolero': 3.0546130545568873,
#  'proud': 1.3577150067113235,
#  'caramels______________________________': 3.0546130545568873,
#  'shred': 1.8302489189753377,
#  'shameful': 2.75396586586516,
#  'faunus': 3.0546130545568873,
#  'container': 1.334453751150931,
#  'fresno': 2.3571722577230334,
#  'stirfry': 2.75396586586516,
#  'measurable': 3.0546130545568873,
#  'hairspray': 2.5782570766553374,
#  'arkham': 2.75396586586516,
#  '0x0c0': 3.0546130545568873,
#  'stiffie': 3.0546130545568873,
#  'barleyell': 3.0546130545568873,
#  'leona': 2.5782570766553374,
#  'noticed': 1.0990319772388213,
#  'oddball': 2.154195657426271,
#  'munition': 2.4537004733597723,
#  'woo': 1.9796242406282818,
#  'kitchenaid': 3.0546130545568873,
#  'satsuki': 2.75396586586516,
#  'birk': 2.5782570766553374,
#  'dramatize': 3.0546130545568873,
#  'quaters': 3.0546130545568873,
#  'sweatband': 2.75396586586516,
#  'hr': 1.5233747984261048,
#  'i0': 3.0546130545568873,
#  'costly': 2.0580462303952816,
#  'tournament': 2.0170333392987803,
#  'bolshevik': 3.0546130545568873,
#  'kadoogan': 3.0546130545568873,
#  'cosmo': 3.0546130545568873,
#  'dble': 3.0546130545568873,
#  'therefor': 3.0546130545568873,
#  'sec': 1.6831221172401434,
#  'bafo': 3.0546130545568873,
#  'grim': 1.739986514085793,
#  'charlie': 1.5611759470421318,
#  'blubber': 3.0546130545568873,
#  'noh': 2.75396586586516,
#  'fdisk': 3.0546130545568873,
#  'untraveled': 3.0546130545568873,
#  'tsie': 3.0546130545568873,
#  'sue': 1.5745912864795968,
#  'tinseth': 3.0546130545568873,
#  'suspected': 1.7012299980669172,
#  'mangle': 2.3571722577230334,
#  'nuturing': 3.0546130545568873,
#  'explaination': 3.0546130545568873,
#  'implicit': 2.4537004733597723,
#  'widely': 1.4369388661605331,
#  'emotionally': 1.8838506290062733,
#  '16th': 2.0580462303952816,
#  'anthem': 1.9452412653245341,
#  'thinker': 2.154195657426271,
#  'noticeable': 2.154195657426271,
#  'bureaucratic': 2.2783724736954567,
#  'frick': 2.75396586586516,
#  'hostility': 2.5782570766553374,
#  'phillipines': 3.0546130545568873,
#  'figured': 1.3910086602379275,
#  'slows': 2.211806811322216,
#  'addictive': 2.75396586586516,
#  'throughly': 3.0546130545568873,
#  'ragged': 2.103423594470504,
#  'valkyrie': 2.3571722577230334,
#  'ina': 2.5782570766553374,
#  'techie': 2.4537004733597723,
#  'inelegant': 3.0546130545568873,
#  'queasy': 2.4537004733597723,
#  'mnemosyne': 2.75396586586516,
#  'rangs': 3.0546130545568873,
#  'blink': 2.154195657426271,
#  'uality': 2.4537004733597723,
#  'paired': 2.5782570766553374,
#  'heuristically': 3.0546130545568873,
#  'martell': 2.2783724736954567,
#  'lawson': 3.0546130545568873,
#  'madras': 2.75396586586516,
#  'antonacci': 3.0546130545568873,
#  'brood': 2.75396586586516,
#  'awning': 3.0546130545568873,
#  'identified': 1.649110087992778,
#  'welcome': 1.1157167091273055,
#  'cantua': 3.0546130545568873,
#  'tux': 2.4537004733597723,
#  'smyvie': 3.0546130545568873,
#  'garde': 2.3571722577230334,
#  'trusix': 3.0546130545568873,
#  'affinity': 2.4537004733597723,
#  'malefactor': 3.0546130545568873,
#  'procrastinate': 2.75396586586516,
#  'seconded': 2.5782570766553374,
#  'scarett': 2.75396586586516,
#  'calvinistic': 3.0546130545568873,
#  'annilihate': 3.0546130545568873,
#  'x5f4': 3.0546130545568873,
#  'gurnee': 3.0546130545568873,
#  'com64': 3.0546130545568873,
#  'misery': 1.8058028185264856,
#  'sprintlink': 3.0546130545568873,
#  'dictator': 2.0580462303952816,
#  'hood': 1.5355919390031147,
#  'selina': 3.0546130545568873,
#  'paralyze': 3.0546130545568873,
#  'snug': 3.0546130545568873,
#  'worldshop': 3.0546130545568873,
#  'eiffel': 2.75396586586516,
#  'istory': 3.0546130545568873,
#  'schoolmarm': 2.75396586586516,
#  'sar': 2.75396586586516,
#  'cking': 2.75396586586516,
#  '5q': 3.0546130545568873,
#  'sincerest': 2.4537004733597723,
#  'toolbox': 2.75396586586516,
#  'interlisp': 3.0546130545568873,
#  'comedomes': 3.0546130545568873,
#  'miscue': 2.75396586586516,
#  'secondly': 2.103423594470504,
#  'inwardly': 2.5782570766553374,
#  'underlying': 2.211806811322216,
#  'usa': 1.3740147402919114,
#  'mistranslation': 3.0546130545568873,
#  'breakdancing': 2.3571722577230334,
#  'messerschmidt': 2.75396586586516,
#  'evolutionary': 2.5782570766553374,
#  'tomondondy': 3.0546130545568873,
#  'grailen': 3.0546130545568873,
#  '37pm': 3.0546130545568873,
#  'ix': 1.782698878134364,
#  'assimilate': 2.3571722577230334,
#  'maude': 2.75396586586516,
#  'criticizes': 3.0546130545568873,
#  'luci': 3.0546130545568873,
#  'interlibrary': 3.0546130545568873,
#  'scratched': 2.0580462303952816,
#  'vdfm': 3.0546130545568873,
#  'morse': 2.211806811322216,
#  'wpfc': 3.0546130545568873,
#  'formulation': 2.4537004733597723,
#  'hyperspace': 2.5782570766553374,
#  'diku': 3.0546130545568873,
#  'definition': 1.3054242437620733,
#  'misspelling': 2.4537004733597723,
#  'appreciation': 1.9796242406282818,
#  'cleanup': 2.2783724736954567,
#  'speed': 0.9756718165186336,
#  'hansen': 2.5782570766553374,
#  'earthly': 2.75396586586516,
#  'treat': 1.3997841493704077,
#  'sheidlower': 3.0546130545568873,
#  'cabbome': 3.0546130545568873,
#  'payton': 3.0546130545568873,
#  'joyride': 3.0546130545568873,
#  'sfmru': 3.0546130545568873,
#  'touchy': 2.4537004733597723,
#  'exploder': 3.0546130545568873,
#  'broiling': 2.5782570766553374,
#  'oahu': 3.0546130545568873,
#  'noyau': 3.0546130545568873,
#  'trashing': 2.4537004733597723,
#  'annually': 2.5782570766553374,
#  'whistling': 2.211806811322216,
#  'kool': 1.8058028185264856,
#  'eyelet': 2.75396586586516,
#  'goofe': 2.75396586586516,
#  'cattle': 1.649110087992778,
#  'juanita': 3.0546130545568873,
#  '7r': 3.0546130545568873,
#  'selected': 1.4887732984555528,
#  'suspicious': 1.6028081301553556,
#  'goulash': 2.3571722577230334,
#  'honigberg': 3.0546130545568873,
#  'grading': 3.0546130545568873,
#  'perman': 3.0546130545568873,
#  'goodyear': 2.5782570766553374,
#  'natsci': 2.75396586586516,
#  'integro': 3.0546130545568873,
#  'technobabble': 3.0546130545568873,
#  'faculty': 1.85620004603236,
#  'shigeta': 2.75396586586516,
#  'bissell': 3.0546130545568873,
#  'sabe': 3.0546130545568873,
#  '8x8': 3.0546130545568873,
#  'grapelets': 3.0546130545568873,
#  'silverclaws': 2.75396586586516,
#  'shaved': 2.0580462303952816,
#  'yusha': 3.0546130545568873,
#  'masur': 3.0546130545568873,
#  'goldstone': 2.5782570766553374,
#  'thingamabob': 3.0546130545568873,
#  'detailed': 1.6176741883963546,
#  'gummed': 2.5782570766553374,
#  'earshot': 2.154195657426271,
#  'blackguard': 3.0546130545568873,
#  'toll': 1.6028081301553556,
#  'resisting': 2.211806811322216,
#  'filter': 1.7607993116307175,
#  'brundin': 2.75396586586516,
#  'pilgrimage': 2.75396586586516,
#  'luvvies': 2.75396586586516,
#  'uucico': 3.0546130545568873,
#  'grouting': 2.5782570766553374,
#  'osteoporosis': 2.5782570766553374,
#  'mykelti': 3.0546130545568873,
#  'supramitive': 3.0546130545568873,
#  'dobb': 3.0546130545568873,
#  'enjoyed': 1.408755973413515,
#  'swastika': 2.4537004733597723,
#  'dermatitis': 2.75396586586516,
#  'axolotl': 2.75396586586516,
#  'otgether': 3.0546130545568873,
#  'chrs': 3.0546130545568873,
#  'sobriety': 2.75396586586516,
#  'confiding': 3.0546130545568873,
#  'dull': 1.6028081301553556,
#  'owen': 1.8838506290062733,
#  'order': 0.6860766427024895,
#  'hed': 2.75396586586516,
#  'commit': 1.6657685507193798,
#  'featurs': 3.0546130545568873,
#  'blindly': 2.2783724736954567,
#  'flippy': 2.5782570766553374,
#  'cleanel': 3.0546130545568873,
#  'thwacko': 3.0546130545568873,
#  'quaky': 3.0546130545568873,
#  'masalas': 3.0546130545568873,
#  'as10g5': 3.0546130545568873,
#  'microdot': 3.0546130545568873,
#  'pearly': 2.5782570766553374,
#  'musican': 3.0546130545568873,
#  'gloopy': 3.0546130545568873,
#  'angst': 2.211806811322216,
#  'tito': 2.75396586586516,
#  'more': 2.4537004733597723,
#  'dichotomy': 3.0546130545568873,
#  'shorter': 1.649110087992778,
#  'strawbs': 3.0546130545568873,
#  'wollongong': 3.0546130545568873,
#  'bimmed': 3.0546130545568873,
#  'supplied': 1.7201593034059568,
#  'giorgio': 3.0546130545568873,
#  'pretext': 2.4537004733597723,
#  'embedded': 2.211806811322216,
#  'pinstripe': 2.5782570766553374,
#  'sandy': 1.8838506290062733,
#  'guinessis': 3.0546130545568873,
#  'rumour': 1.326993827612491,
#  'prometheus': 2.3571722577230334,
#  'eeyore': 3.0546130545568873,
#  'hiroyuki': 3.0546130545568873,
#  'covertly': 2.5782570766553374,
#  'pharmacopoeia': 3.0546130545568873,
#  'veteran': 1.7607993116307175,
#  'ames': 1.8302489189753377,
#  'swap': 1.9452412653245341,
#  'ahram': 3.0546130545568873,
#  '__sloppy': 2.75396586586516,
#  'dietrich': 2.2783724736954567,
#  'kelsey': 2.4537004733597723,
#  'animosity': 2.75396586586516,
#  'sneed': 2.75396586586516,
#  'slanted': 3.0546130545568873,
#  'lentil': 2.4537004733597723,
#  'yor': 3.0546130545568873,
#  'security': 1.1287400254884488,
#  'trodden': 3.0546130545568873,
#  'heartland': 2.75396586586516,
#  'flume': 3.0546130545568873,
#  'sugur': 3.0546130545568873,
#  'arachnophobia': 3.0546130545568873,
#  'diablospores': 3.0546130545568873,
#  'lemieuxf': 3.0546130545568873,
#  'outlawed': 2.0170333392987803,
#  'sundown': 3.0546130545568873,
#  'swerved': 2.5782570766553374,
#  '3655e': 3.0546130545568873,
#  'skydiver': 3.0546130545568873,
#  'secular': 2.5782570766553374,
#  'vita': 2.75396586586516,
#  'alberto': 2.75396586586516,
#  'referred': 1.3498088194274545,
#  'watson': 1.9134353822230294,
#  'queue': 2.0580462303952816,
#  'disgruntled': 2.0580462303952816,
#  'floating': 1.417932776675739,
#  'saddle': 2.103423594470504,
#  '285f': 3.0546130545568873,
#  'squishers': 3.0546130545568873,
#  'salinger': 2.75396586586516,
#  'masaru': 3.0546130545568873,
#  'mbj': 3.0546130545568873,
#  'bimattress': 3.0546130545568873,
#  'dispel': 3.0546130545568873,
#  'uh': 1.212475550366373,
#  'harmed': 2.75396586586516,
#  'strode': 2.4537004733597723,
#  'hoax': 2.154195657426271,
#  'puffer': 2.75396586586516,
#  'yorter': 3.0546130545568873,
#  '11am': 2.5782570766553374,
#  'nepean': 3.0546130545568873,
#  'cumpny': 3.0546130545568873,
#  'bawd': 3.0546130545568873,
#  'monotone': 3.0546130545568873,
#  'futuristic': 2.3571722577230334,
#  'breakthrough': 2.154195657426271,
#  'jingle': 2.0580462303952816,
#  'operation': 1.1422329917947138,
#  'act': 0.895790748250444,
#  'fingerfood': 3.0546130545568873,
#  'katrina': 2.3571722577230334,
#  'wildhack': 3.0546130545568873,
#  'dabbled': 3.0546130545568873,
#  'tango': 3.0546130545568873,
#  'racially': 3.0546130545568873,
#  'dianes': 3.0546130545568873,
#  'kno': 2.75396586586516,
#  'annese': 2.75396586586516,
#  'drama': 1.5884584600087859,
#  'moynes': 3.0546130545568873,
#  'drape': 1.9134353822230294,
#  'pdr': 2.75396586586516,
#  'blamed': 1.9134353822230294,
#  'corleone': 3.0546130545568873,
#  'mistreating': 3.0546130545568873,
#  'satire': 1.9452412653245341,
#  'busuness': 3.0546130545568873,
#  'departure': 1.9452412653245341,
#  'fort': 1.9796242406282818,
#  'briefcase': 1.85620004603236,
#  'alter': 1.7201593034059568,
#  'schaken': 3.0546130545568873,
#  'bollo': 3.0546130545568873,
#  'appellerait': 2.75396586586516,
#  'khuit': 3.0546130545568873,
#  'rig': 2.154195657426271,
#  'acker': 2.75396586586516,
#  'agency': 1.3910086602379275,
#  'lime': 1.5355919390031147,
#  'olivia': 2.154195657426271,
#  'technics': 3.0546130545568873,
#  'whoozits': 3.0546130545568873,
#  'bmoconno': 3.0546130545568873,
#  'wumpuss': 3.0546130545568873,
#  'bronwen': 3.0546130545568873,
#  'klooish': 3.0546130545568873,
#  'inconstancy': 3.0546130545568873,
#  'ssg': 3.0546130545568873,
#  'shill': 2.75396586586516,
#  'harvard': 1.6831221172401434,
#  'oids': 3.0546130545568873,
#  'bathhouse': 3.0546130545568873,
#  'amusedly': 3.0546130545568873,
#  'baja': 3.0546130545568873,
#  'autry': 2.75396586586516,
#  'anudder': 3.0546130545568873,
#  'wicker': 2.5782570766553374,
#  'shaky': 2.154195657426271,
#  'aliased': 3.0546130545568873,
#  'critic': 1.649110087992778,
#  'darby': 2.75396586586516,
#  'flick': 1.85620004603236,
#  'toresby': 3.0546130545568873,
#  'allman': 3.0546130545568873,
#  'clunky': 3.0546130545568873,
#  'battis': 2.75396586586516,
#  'pissed': 1.5884584600087859,
#  'bumped': 2.5782570766553374,
#  'ibew': 3.0546130545568873,
#  'gifted': 2.0170333392987803,
#  'mmmmph': 3.0546130545568873,
#  'wo': 2.4537004733597723,
#  'wandering': 1.8302489189753377,
#  'lifesized': 3.0546130545568873,
#  'macht': 2.75396586586516,
#  'provoke': 2.4537004733597723,
#  'cerimonial': 3.0546130545568873,
#  'strident': 2.75396586586516,
#  'sap': 2.154195657426271,
#  'wallpaper': 2.4537004733597723,
#  'wulfgar': 3.0546130545568873,
#  'ginseng': 3.0546130545568873,
#  'firewater': 3.0546130545568873,
#  'nz': 2.211806811322216,
#  'w_': 3.0546130545568873,
#  'mayonnaise': 1.9452412653245341,
#  'hu': 2.5782570766553374,
#  'sh': 1.9796242406282818,
#  'waste': 1.151505254374814,
#  'scratchabacha': 3.0546130545568873,
#  'athon': 3.0546130545568873,
#  'fester': 3.0546130545568873,
#  'cunthooks': 3.0546130545568873,
#  'mcpo': 3.0546130545568873,
#  'lundy': 3.0546130545568873,
#  'brave': 1.5611759470421318,
#  'mediocrity': 2.2783724736954567,
#  'moll': 3.0546130545568873,
#  'handcuff': 2.154195657426271,
#  'cygnus': 2.5782570766553374,
#  'angrier': 3.0546130545568873,
#  'landreth': 3.0546130545568873,
#  'overcompensate': 3.0546130545568873,
#  'parralel': 3.0546130545568873,
#  'mineral': 1.8302489189753377,
#  'majority': 1.3740147402919114,
#  'rumma': 3.0546130545568873,
#  'dubrin': 3.0546130545568873,
#  'biu': 3.0546130545568873,
#  'knoweth': 2.75396586586516,
#  'superstardom': 2.5782570766553374,
#  'affliction': 3.0546130545568873,
#  'harty': 3.0546130545568873,
#  'noteys': 3.0546130545568873,
#  'expense': 1.4672380207875668,
#  'interchange': 2.2783724736954567,
#  'hiya': 2.4537004733597723,
#  'untouchable': 2.5782570766553374,
#  'entropically': 3.0546130545568873,
#  'wishine': 3.0546130545568873,
#  'slimeball': 3.0546130545568873,
#  'diad': 3.0546130545568873,
#  'mattingly': 2.75396586586516,
#  'tron': 2.75396586586516,
#  'passover': 2.5782570766553374,
#  'puttem': 3.0546130545568873,
#  'callin': 2.75396586586516,
#  'gored': 3.0546130545568873,
#  'january': 1.417932776675739,
#  'murries': 3.0546130545568873,
#  'physique': 2.5782570766553374,
#  'blud': 3.0546130545568873,
#  'tumour': 3.0546130545568873,
#  'pingon': 3.0546130545568873,
#  'valiantly': 2.5782570766553374,
#  'saltpetre': 3.0546130545568873,
#  'evx': 3.0546130545568873,
#  'supergirl': 2.5782570766553374,
#  'tale': 1.2410553769294654,
#  'spied': 3.0546130545568873,
#  'antiperspirant': 3.0546130545568873,
#  'jointly': 2.5782570766553374,
#  'alla': 3.0546130545568873,
#  'seawasp': 3.0546130545568873,
#  'martin': 1.2849762157859024,
#  'nuit': 2.75396586586516,
#  'dedaparamaxx': 2.3571722577230334,
#  'damned': 1.633094225067931,
#  'schedule': 1.4778630046555723,
#  'czonka': 3.0546130545568873,
#  'nembutol': 3.0546130545568873,
#  'pie': 1.3997841493704077,
#  'severed': 2.154195657426271,
#  'christina': 2.5782570766553374,
#  'nightgown': 2.4537004733597723,
#  '20pm': 2.75396586586516,
#  'meeeeeeelllllllllllltttttttttttiiiiiiiinnnnnnnnngggg': 2.75396586586516,
#  'genoa': 3.0546130545568873,
#  'gringo': 3.0546130545568873,
#  'emolliation': 3.0546130545568873,
#  'yasensky': 3.0546130545568873,
#  'dlk': 3.0546130545568873,
#  'ethic': 1.739986514085793,
#  'overnite': 3.0546130545568873,
#  'cataclysm': 2.5782570766553374,
#  'mgh': 3.0546130545568873,
#  'tolerant': 2.75396586586516,
#  'prequel': 3.0546130545568873,
#  'dracula': 2.3571722577230334,
#  'chimed': 2.4537004733597723,
#  'stringfellow': 3.0546130545568873,
#  'theophylline': 3.0546130545568873,
#  'voluem': 3.0546130545568873,
#  'lance': 1.85620004603236,
#  'aaagh': 3.0546130545568873,
#  'duster': 2.75396586586516,
#  'reclined': 2.75396586586516,
#  'tblspoons': 3.0546130545568873,
#  'proprietor': 2.4537004733597723,
#  'job': 0.7544873321858501,
#  'intestinal': 2.2783724736954567,
#  'grunt': 1.85620004603236,
#  'tibetians': 3.0546130545568873,
#  'concubine': 3.0546130545568873,
#  'compability': 3.0546130545568873,
#  'liv': 2.4537004733597723,
#  'arsonous': 3.0546130545568873,
#  'yr': 2.154195657426271,
#  'eva': 2.0580462303952816,
#  'ambsadors': 3.0546130545568873,
#  'vincing': 3.0546130545568873,
#  'thania': 3.0546130545568873,
#  'angiocardiography': 3.0546130545568873,
#  'jetsons': 3.0546130545568873,
#  'oriface': 3.0546130545568873,
#  'bassinet': 3.0546130545568873,
#  'awesomest': 3.0546130545568873,
#  'lubbilubbing': 3.0546130545568873,
#  'queen': 1.417932776675739,
#  'theoretical': 1.6028081301553556,
#  'liberation': 1.9452412653245341,
#  'jile': 3.0546130545568873,
#  'linden': 2.3571722577230334,
#  'conreid': 3.0546130545568873,
#  'yous': 3.0546130545568873,
#  'pooing': 3.0546130545568873,
#  'dismounted': 3.0546130545568873,
#  'undermined': 2.5782570766553374,
#  'pal': 1.5233747984261048,
#  'moore': 1.85620004603236,
#  'cuppa': 2.75396586586516,
#  'circle': 1.1376811992616227,
#  'tuscaloosa': 3.0546130545568873,
#  'monmouthshire': 3.0546130545568873,
#  'belonged': 1.9452412653245341,
#  'kettle': 1.85620004603236,
#  'lom': 2.75396586586516,
#  'stormy': 2.211806811322216,
#  'vtam': 3.0546130545568873,
#  'staked': 2.5782570766553374,
#  'obtaining': 2.103423594470504,
#  'fibula': 3.0546130545568873,
#  'authoritative': 2.75396586586516,
#  'volition': 3.0546130545568873,
#  'covert': 2.2783724736954567,
#  'giguere': 3.0546130545568873,
#  'voracity': 3.0546130545568873,
#  'combust': 2.75396586586516,
#  'whitespace': 3.0546130545568873,
#  'baptised': 3.0546130545568873,
#  'nutient': 3.0546130545568873,
#  'ferkin': 3.0546130545568873,
#  'curie': 2.75396586586516,
#  'flouts': 3.0546130545568873,
#  'helplessness': 3.0546130545568873,
#  'bide': 3.0546130545568873,
#  'hmmmmm': 2.3571722577230334,
#  'dolly': 2.211806811322216,
#  'ctv': 2.75396586586516,
#  'busting': 2.3571722577230334,
#  't4910799104581': 3.0546130545568873,
#  'contaminatid': 3.0546130545568873,
#  'asphyxiate': 3.0546130545568873,
#  'seemingly': 1.6176741883963546,
#  '2q44it': 3.0546130545568873,
#  'twain': 1.9796242406282818,
#  'conservatively': 3.0546130545568873,
#  'chill': 1.4778630046555723,
#  'gockel': 3.0546130545568873,
#  'shrine': 1.649110087992778,
#  'clueless': 1.9452412653245341,
#  'framed': 1.9796242406282818,
#  'delfino': 3.0546130545568873,
#  'jun20': 3.0546130545568873,
#  'larron': 3.0546130545568873,
#  'uninterrupted': 2.75396586586516,
#  'v2': 2.3571722577230334,
#  'spuck': 3.0546130545568873,
#  '130f': 3.0546130545568873,
#  'everyting': 3.0546130545568873,
#  'harem': 2.5782570766553374,
#  'celle': 3.0546130545568873,
#  'german': 1.2016127085799804,
#  'bolt': 1.6176741883963546,
#  'slidy': 3.0546130545568873,
#  'lasciviously': 3.0546130545568873,
#  'poleon': 3.0546130545568873,
#  'pemberton': 2.5782570766553374,
#  'disbelief': 1.9452412653245341,
#  'recounted': 2.4537004733597723,
#  'foac': 3.0546130545568873,
#  'lobster': 1.9134353822230294,
#  'comput': 3.0546130545568873,
#  'postzug': 3.0546130545568873,
#  'birdwatchers': 3.0546130545568873,
#  'ruinous': 2.75396586586516,
#  'looseleaf': 3.0546130545568873,
#  'accross': 2.5782570766553374,
#  'telethon': 2.4537004733597723,
#  'wichers': 2.75396586586516,
#  'rodin': 3.0546130545568873,
#  'amin': 2.211806811322216,
#  'regognition': 3.0546130545568873,
#  'teenybopper': 2.75396586586516,
#  'ess1a': 3.0546130545568873,
#  'directons': 3.0546130545568873,
#  'shepered': 3.0546130545568873,
#  'inxs': 2.4537004733597723,
#  'cjlb': 3.0546130545568873,
#  'mousy': 3.0546130545568873,
#  'mopar': 2.75396586586516,
#  'glared': 2.75396586586516,
#  'obake': 3.0546130545568873,
#  'dolphin': 2.0170333392987803,
#  'nonrefundable': 3.0546130545568873,
#  '49th': 3.0546130545568873,
#  'unsubscribed': 3.0546130545568873,
#  'bly': 2.75396586586516,
#  'examining': 1.7607993116307175,
#  'ewar': 3.0546130545568873,
#  'flinchy': 3.0546130545568873,
#  'sympathizing': 3.0546130545568873,
#  'prated': 3.0546130545568873,
#  'nevil': 3.0546130545568873,
#  'crasher': 2.75396586586516,
#  'surfactant': 2.75396586586516,
#  'sux': 2.4537004733597723,
#  'yog': 2.75396586586516,
#  'hac2arpa': 3.0546130545568873,
#  'trevor': 2.154195657426271,
#  'bcv': 3.0546130545568873,
#  '900l': 3.0546130545568873,
#  'recall_': 3.0546130545568873,
#  'spanning': 3.0546130545568873,
#  'diehl': 3.0546130545568873,
#  'roving': 2.3571722577230334,
#  'joris': 3.0546130545568873,
#  'itzin': 2.75396586586516,
#  'greed': 1.9796242406282818,
#  'rassoodock': 3.0546130545568873,
#  'overconfidence': 3.0546130545568873,
#  'brunt': 2.2783724736954567,
#  'haynes': 3.0546130545568873,
#  'sectioning': 3.0546130545568873,
#  'clearinghouse': 3.0546130545568873,
#  'gumdrop': 2.5782570766553374,
#  'fitwer': 3.0546130545568873,
#  'horndog': 3.0546130545568873,
#  'purloined': 3.0546130545568873,
#  'beehive': 2.75396586586516,
#  'bloop': 2.75396586586516,
#  'detabooization': 3.0546130545568873,
#  '14h10': 3.0546130545568873,
#  'burly': 2.75396586586516,
#  'afula': 3.0546130545568873,
#  '____________________________': 2.3571722577230334,
#  'mondale': 2.2783724736954567,
#  'strained': 1.9134353822230294,
#  'slayden': 3.0546130545568873,
#  'determines': 2.103423594470504,
#  'whoa': 1.8838506290062733,
#  '_a_day_in_beaumont': 3.0546130545568873,
#  'interchangeability': 3.0546130545568873,
#  'calorimetry': 3.0546130545568873,
#  'purported': 2.5782570766553374,
#  'tyrany': 2.75396586586516,
#  'weightless': 3.0546130545568873,
#  'outcast': 2.211806811322216,
#  'terrian': 3.0546130545568873,
#  'redirected': 3.0546130545568873,
#  'dumb': 1.4369388661605331,
#  'feminine': 2.211806811322216,
#  'lhi': 3.0546130545568873,
#  'verda': 3.0546130545568873,
#  'ewen': 3.0546130545568873,
#  'londoner': 2.5782570766553374,
#  'usgs': 3.0546130545568873,
#  'retains': 2.75396586586516,
#  'killed': 1.0566950978999377,
#  'bloat': 3.0546130545568873,
#  'streynour': 3.0546130545568873,
#  'lymricks': 3.0546130545568873,
#  'trump': 2.2783724736954567,
#  'argh': 2.5782570766553374,
#  'cross': 1.0253753023872945,
#  'neightbors': 3.0546130545568873,
#  'compatibles': 3.0546130545568873,
#  'offer': 0.9996551849902996,
#  'lund': 2.75396586586516,
#  'elric': 2.75396586586516,
#  'constrictor': 2.2783724736954567,
#  'enloe': 2.75396586586516,
#  'lustre': 2.75396586586516,
#  'button': 1.1287400254884488,
#  'suctum': 3.0546130545568873,
#  'noticing': 2.0170333392987803,
#  'consummate': 3.0546130545568873,
#  'vicki': 2.3571722577230334,
#  'unassuaged': 3.0546130545568873,
#  'huevos': 3.0546130545568873,
#  'wildman': 2.5782570766553374,
#  'undergrad': 2.2783724736954567,
#  'updraft': 3.0546130545568873,
#  'hangout': 2.211806811322216,
#  'kelpy': 3.0546130545568873,
#  'okb': 3.0546130545568873,
#  'timism': 3.0546130545568873,
#  'power': 0.757459295525149,
#  'ek': 3.0546130545568873,
#  'moriarti': 3.0546130545568873,
#  'publishes': 2.2783724736954567,
#  'sna': 2.75396586586516,
#  'agva': 3.0546130545568873,
#  'fallout': 2.211806811322216,
#  'disapproves': 3.0546130545568873,
#  'inbetweeners': 3.0546130545568873,
#  'dwindling': 2.75396586586516,
#  'legitimately': 2.5782570766553374,
#  'installed': 1.5611759470421318,
#  'nagel': 2.75396586586516,
#  'lc': 2.75396586586516,
#  'fairhaired': 3.0546130545568873,
#  'defeat': 1.9134353822230294,
#  'sexploitation': 3.0546130545568873,
#  'vasodilator': 3.0546130545568873,
#  'comely': 3.0546130545568873,
#  'turtiainen': 3.0546130545568873,
#  'mummify': 3.0546130545568873,
#  'cassius': 3.0546130545568873,
#  'vols': 3.0546130545568873,
#  'larouche': 2.4537004733597723,
#  'weekz': 3.0546130545568873,
#  'hubley': 2.75396586586516,
#  'vvss': 3.0546130545568873,
#  'quicksave': 3.0546130545568873,
#  'gousse': 2.75396586586516,
#  'propogated': 3.0546130545568873,
#  'bilateral': 3.0546130545568873,
#  'audience': 1.3054242437620733,
#  'crummy': 2.5782570766553374,
#  'unsensual': 2.75396586586516,
#  'huffy': 3.0546130545568873,
#  'elevated': 2.3571722577230334,
#  'lapel': 2.75396586586516,
#  'pilar': 3.0546130545568873,
#  'grassland': 3.0546130545568873,
#  'desolve': 3.0546130545568873,
#  'sensed': 2.4537004733597723,
#  'chloro': 3.0546130545568873,
#  'torpedoed': 3.0546130545568873,
#  'ampersand': 2.5782570766553374,
#  'muscleheads': 3.0546130545568873,
#  'nabob': 3.0546130545568873,
#  'lh': 2.75396586586516,
#  'gebhardt': 2.4537004733597723,
#  '9f11': 3.0546130545568873,
#  'dre': 3.0546130545568873,
#  'thetransition': 3.0546130545568873,
#  'cop': 1.25927524755698,
#  'loudened': 3.0546130545568873,
#  'colossal': 2.3571722577230334,
#  'humour': 1.9452412653245341,
#  'grammatical': 2.0580462303952816,
#  'hki': 3.0546130545568873,
#  'drowns': 2.2783724736954567,
#  'erikson': 2.75396586586516,
#  'funky': 2.154195657426271,
#  'loot': 2.103423594470504,
#  'ss1': 2.75396586586516,
#  'pla': 2.75396586586516,
#  'kleina': 3.0546130545568873,
#  'tattle': 3.0546130545568873,
#  'mcarthy': 2.75396586586516,
#  'mize': 3.0546130545568873,
#  'gyngere': 3.0546130545568873,
#  'prejudice': 2.154195657426271,
#  'dijon': 2.4537004733597723,
#  '______21': 3.0546130545568873,
#  'fredricks': 3.0546130545568873,
#  'zany': 2.75396586586516,
#  'playdon': 3.0546130545568873,
#  'librarian': 2.3571722577230334,
#  '4pounds': 3.0546130545568873,
#  'astonomers': 3.0546130545568873,
#  'rust': 1.9452412653245341,
#  'sebert': 3.0546130545568873,
#  'laff': 2.5782570766553374,
#  'excuse': 1.2655434614104368,
#  'modeler': 2.75396586586516,
#  'jfk': 2.154195657426271,
#  'hospitalization': 3.0546130545568873,
#  'bowler': 2.3571722577230334,
#  'archbishop': 2.5782570766553374,
#  'vomit': 1.9796242406282818,
#  'shaughnessy': 2.75396586586516,
#  'drinkin': 2.5782570766553374,
#  'tracing': 2.2783724736954567,
#  'rrrboat': 3.0546130545568873,
#  'spewy': 3.0546130545568873,
#  'mankind': 1.7012299980669172,
#  'edc3jr': 3.0546130545568873,
#  'thereto': 2.75396586586516,
#  'maniacal': 2.3571722577230334,
#  'appetizingly': 3.0546130545568873,
#  'noteworthy': 2.75396586586516,
#  'bible': 1.4778630046555723,
#  'epaulet': 2.75396586586516,
#  'oceanic': 3.0546130545568873,
#  'molesting': 2.4537004733597723,
#  '_________________________________': 2.5782570766553374,
#  'xeroxing': 3.0546130545568873,
#  'hinduism': 3.0546130545568873,
#  'ecologically': 2.4537004733597723,
#  'valenza': 2.75396586586516,
#  'preconception': 3.0546130545568873,
#  'dy': 1.4369388661605331,
#  'bimbeaver': 3.0546130545568873,
#  'elan': 2.75396586586516,
#  'stylistically': 3.0546130545568873,
#  'unrighteous': 3.0546130545568873,
#  'hobart': 2.75396586586516,
#  'involuntary': 2.75396586586516,
#  '24a': 3.0546130545568873,
#  'lpas': 3.0546130545568873,
#  'caffinated': 3.0546130545568873,
#  'organised': 2.75396586586516,
#  'momentarily': 2.5782570766553374,
#  'thereupon': 2.75396586586516,
#  'skorry': 3.0546130545568873,
#  'minoru': 3.0546130545568873,
#  'bipedal': 2.75396586586516,
#  'independ': 3.0546130545568873,
#  'viejo': 3.0546130545568873,
#  'conjured': 2.5782570766553374,
#  'jtrim': 3.0546130545568873,
#  'singate': 3.0546130545568873,
#  'uncontrolable': 3.0546130545568873,
#  'chamberline': 2.75396586586516,
#  'turnstile': 2.5782570766553374,
#  'chirstmas': 2.75396586586516,
#  'aaaaaaaaaaaaaaaaaaaaggggggggggggggggggggggggggghhhhhhhhhhhhhhh': 3.0546130545568873,
#  'nm': 2.2783724736954567,
#  'overture': 2.4537004733597723,
#  'reeling': 2.5782570766553374,
#  'isaak': 2.5782570766553374,
#  'entymologists': 2.75396586586516,
#  '377b': 3.0546130545568873,
#  'weepy': 3.0546130545568873,
#  'despondent': 2.75396586586516,
#  'truthfulness': 3.0546130545568873,
#  'challenge': 1.3498088194274545,
#  'uvic': 2.3571722577230334,
#  'milk': 1.0253753023872945,
#  'abit': 3.0546130545568873,
#  'illuminati': 2.5782570766553374,
#  'bbn': 2.211806811322216,
#  'distrust': 2.4537004733597723,
#  'proximity': 2.3571722577230334,
#  'trachea': 2.75396586586516,
#  'straightened': 2.3571722577230334,
#  'isabella': 2.5782570766553374,
#  'prisoner': 1.633094225067931,
#  'm1pq': 3.0546130545568873,
#  'majorana': 2.5782570766553374,
#  'jona': 2.75396586586516,
#  'springfield': 2.154195657426271,
#  'secretly': 1.8838506290062733,
#  'heatproof': 2.75396586586516,
#  'zerth': 3.0546130545568873,
#  'malignant': 2.75396586586516,
#  'approching': 3.0546130545568873,
#  '___________________________________________________________________________________': 3.0546130545568873,
#  'teahouse': 3.0546130545568873,
#  'pentametric': 3.0546130545568873,
#  'nickname': 1.8302489189753377,
#  'fogey': 2.75396586586516,
#  'clockwise': 2.211806811322216,
#  'sighted': 2.211806811322216,
#  'panther': 2.75396586586516,
#  'inheriting': 2.5782570766553374,
#  'shoehorn': 2.5782570766553374,
#  'samarai': 3.0546130545568873,
#  'moldering': 3.0546130545568873,
#  'costume': 1.5745912864795968,
#  'greedily': 3.0546130545568873,
#  'confuscius': 3.0546130545568873,
#  'loudly': 1.5481846105451076,
#  'diverticular': 3.0546130545568873,
#  'stiver': 3.0546130545568873,
#  'missin': 3.0546130545568873,
#  'buildup': 2.75396586586516,
#  'ecn': 3.0546130545568873,
#  'fated': 2.5782570766553374,
#  'joshu': 2.75396586586516,
#  'tarantella': 3.0546130545568873,
#  'mulrine': 3.0546130545568873,
#  'arora': 3.0546130545568873,
#  'waddle': 2.5782570766553374,
#  'athhole': 3.0546130545568873,
#  'droney': 2.75396586586516,
#  'capacity': 1.7607993116307175,
#  'escaping': 2.103423594470504,
#  'christakis': 3.0546130545568873,
#  'lattimer': 3.0546130545568873,
#  'nde': 3.0546130545568873,
#  'phased': 2.4537004733597723,
#  'flanquer': 2.75396586586516,
#  'institut': 3.0546130545568873,
#  'questionare': 3.0546130545568873,
#  'geneepisdes': 3.0546130545568873,
#  'spud': 2.5782570766553374,
#  'decline': 1.9452412653245341,
#  'ky0lli': 3.0546130545568873,
#  'brann': 3.0546130545568873,
#  'kr': 2.5782570766553374,
#  'bonux': 3.0546130545568873,
#  'melody': 2.0170333392987803,
#  'sob': 2.154195657426271,
#  'playoff': 3.0546130545568873,
#  'saaid': 3.0546130545568873,
#  'overeager': 3.0546130545568873,
#  'rudedog': 3.0546130545568873,
#  'summarizing': 3.0546130545568873,
#  'wink': 1.9452412653245341,
#  'keep': 0.6223745781547657,
#  'upbringing': 2.3571722577230334,
#  'dfd': 3.0546130545568873,
#  'glancing': 2.4537004733597723,
#  'affirmed': 2.75396586586516,
#  'shakily': 3.0546130545568873,
#  'naaah': 3.0546130545568873,
#  'sneezing': 2.4537004733597723,
#  'weygand': 3.0546130545568873,
#  'orzo': 3.0546130545568873,
#  'margherita': 3.0546130545568873,
#  'twinkiness': 3.0546130545568873,
#  'blaze': 2.211806811322216,
#  'snippit': 3.0546130545568873,
#  'nondeterministic': 3.0546130545568873,
#  'inadvisable': 3.0546130545568873,
#  'earnest': 2.2783724736954567,
#  'confuses': 3.0546130545568873,
#  'surrre': 3.0546130545568873,
#  'psychotria': 3.0546130545568873,
#  'humourist': 3.0546130545568873,
#  'lambasts': 2.75396586586516,
#  'remick': 2.75396586586516,
#  'rainin': 2.5782570766553374,
#  'filum': 3.0546130545568873,
#  'rugged': 3.0546130545568873,
#  'deductible': 2.5782570766553374,
#  'merchantville': 3.0546130545568873,
#  'speke': 3.0546130545568873,
#  'squeaked': 3.0546130545568873,
#  'tippi': 2.75396586586516,
#  'variation': 1.3740147402919114,
#  'maelcum': 3.0546130545568873,
#  'being': 1.6831221172401434,
#  'fureys': 3.0546130545568873,
#  'infinity': 1.782698878134364,
#  'erickson': 2.2783724736954567,
#  'initialization': 2.4537004733597723,
#  'dasilva': 3.0546130545568873,
#  'selenene': 3.0546130545568873,
#  'gamnes': 3.0546130545568873,
#  'labrador': 3.0546130545568873,
#  'ronstadt': 3.0546130545568873,
#  'postkanser': 3.0546130545568873,
#  'immensely': 2.3571722577230334,
#  'xref': 2.4537004733597723,
#  'hogan': 2.2783724736954567,
#  'sheeting': 3.0546130545568873,
#  'luton': 3.0546130545568873,
#  'nice': 0.9398926348996921,
#  'awes0me': 3.0546130545568873,
#  'jb': 2.75396586586516,
#  'unimpeachable': 3.0546130545568873,
#  'immortality': 2.103423594470504,
#  'strawe': 3.0546130545568873,
#  'hsu': 3.0546130545568873,
#  'lui': 2.75396586586516,
#  'chud': 3.0546130545568873,
#  'chatcan': 3.0546130545568873,
#  'operating': 1.3420569591316227,
#  'polyychlorinated': 3.0546130545568873,
#  'aerial': 2.0580462303952816,
#  'hal': 1.8838506290062733,
#  'wharton': 2.75396586586516,
#  'd7': 3.0546130545568873,
#  'lorr': 3.0546130545568873,
#  'cliche': 1.8058028185264856,
#  'crunchtv': 3.0546130545568873,
#  'irritate': 2.4537004733597723,
#  'aug22': 3.0546130545568873,
#  'uzziwd40hahew': 3.0546130545568873,
#  'steelers': 3.0546130545568873,
#  'knut': 3.0546130545568873,
#  'gnown': 3.0546130545568873,
#  'baklava': 3.0546130545568873,
#  'darksider': 3.0546130545568873,
#  'reservation': 1.8838506290062733,
#  'trembling': 2.154195657426271,
#  'remotely': 2.103423594470504,
#  'arats': 3.0546130545568873,
#  ...}

# %%
len(idf)
# Out:
# 60765

# %% [markdown]
# BINARY

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
for x in range(1):
  print("")
term={}
for z in tqdm(voc):
  pair={}
  for j in range(len(dict)):
    if z not in dict[j]:
      pair[b[j]]=0
    for x in range(1):
      print("")
    else:
      pair[b[j]]=1
      for x in range(1):
        print("")
    pair[b[j]]=pair[b[j]]/len(e[j])  
  term[z]=pair
for x in range(1):
  print("")
# Out:
# 100%|██████████| 60765/60765 [27:52<00:00, 36.33it/s]

# %%
tf_idf=[]
for x in range(1):
  print("")
for j in tqdm(range(len(dict))):
  s=[]
  for i in voc:
    s.append(term[i][b[j]]*idf[i])
    for x in range(1):
      print("")
  tf_idf.append(s) 
for x in range(1):
  print("")
# Out:
# 100%|██████████| 1133/1133 [01:40<00:00, 11.23it/s]

# %%
len(tf_idf)
# Out:
# 1133

# %%
c=[]
f=[]
sentence=input("Enter your query:")
#Sentence Preprocessing
sentence=''.join('' if c=='.' else c for c in sentence)#normalization
sentence=re.sub(r'[^a-zA-Z]+', ' ',sentence)#removal of punctuations
sentence=sentence.lower()#lower case
tags_pattern=re.compile('<.*?>')
sentence=tags_pattern.sub(r'',sentence)#removal of tags
url_pattern=re.compile(r'https?://\S+|www\.\S+')
sentence=url_pattern.sub(r'',sentence)#removal of url
sentence=" ".join(sentence.split())#removal of extra white spaces
lem=WordNetLemmatizer()#lemmanization
sentence="".join([lem.lemmatize(word) for word in sentence])#lemmanization
words=word_tokenize(sentence)#convert to tokens
#remove stopwords
for word in words:
  if word not in stopwords.words('english'):
    f.append(word)
for x in f:
  if x not in c:
    c.append(x)
# Out:
# Enter your query:cold water

# %%
for x in range(1):
  print("")
d=pd.DataFrame(tf_idf,columns=voc)
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
d1=pd.DataFrame(columns=c)
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
sum_count=0
sort={}
di={}
for i in c:
  for j in range(len(d)):
    d1.at[j,i]=d.at[j,i]
for i in list(d1.columns):
  sum_count=sum_count+d1[i]
  d1['sum']=sum_count
for x in range(1):
  print("")
for i in range(len(d1)):
  di[b[i]]=d1['sum'][i]
  sorted_keys=sorted(di,key=di.get,reverse=True)
  for x in range(1):
    print("")
for i in sorted_keys:
  sort[i]=di[i]
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
a=list(sort.keys())
print(a[0:5])
for x in range(1):
  print("")
# Out:
# ['dym', 'onetoone.hum', 't_zone.jok', 'smurfkil.hum', 'texican.dic']
