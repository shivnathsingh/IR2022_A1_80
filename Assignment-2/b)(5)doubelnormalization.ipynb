# %%
import glob
import os
import string
import nltk
import re
import pandas as pd
import numpy as np

# %%
P="/content/drive/MyDrive/Humor,Hist,Media,Food/*"

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
s=stopwords.words('english')

# %%
a=[]
for i in glob.glob(P):
  a.append("/content/drive/MyDrive/Humor,Hist,Media,Food/"+os.path.basename(i))

# %%
len(a)
# Out:
# 1133

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
from tqdm import tqdm

# %%
import os
import math
import glob
import pandas as pd
import numpy as np
import nltk
import re
nltk.download('stopwords')
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 

import nltk
nltk.download('stopwords')  


nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import gensim
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stop_words = set(stopwords.words('english'));
p_ind={}
dict=[]
e=[]
voc=[]
docid=1
for i in tqdm(range(len(a))):
  with open(a[i],encoding="utf8",errors='ignore') as file:
    c=[]
    text =file.read()
    text=text.lower()   #to convert in to lower case 
    text=text.strip()
    text = re.sub(r'[^\w\s]', ' ', text)  # To remove puntuation
    word_tokens = word_tokenize(text)   # toknization 
    final_tokens=[w for w in word_tokens if w not in stop_words] # stopword remove
    final_tokens=[ lemmatizer.lemmatize(word) for word in final_tokens]
    final_tokens = [x for x in final_tokens if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
    final_tokens=set(final_tokens)
    for term in final_tokens:
      if term not in c:
        c.append(term)
        voc.append(term)
    dict.append(c)  
    e.append(voc)  
    counter=0
    for z in final_tokens:
      if z in p_ind:
          if docid in p_ind[z][1]:
            p_ind[z][1][docid].append(counter)
          else:
            p_ind[z][0]=p_ind[z][0]+1
            p_ind[z][1][docid]=[counter]
            counter+=1
      else:
        p_ind[z]=[]
        p_ind[z].append(1)
        p_ind[z].append({})
        p_ind[z][1][docid]=[counter]
        counter=counter+1
    docid+=1
# Out:
# 100%|██████████| 1133/1133 [00:33<00:00, 33.44it/s]

# %%
voc=list(set(voc))

# %%
counter=0
for x in range(1):
  print("")
list_pos={}
for i in dict:
  counter+=1
  for j in i:
    if j in list_pos:
      list_pos[j].append(counter)
    else:
      list_pos[j]=[counter]
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
idf={}                           
for i in tqdm(range(len(voc))):
  for x in range(1):
    print("")
  a=len(list_pos[voc[i]])
  b=len(dict)
  idf[voc[i]]=math.log((b/a+1),10)
for x in range(1):
  print("")
# Out:
# 100%|██████████| 60765/60765 [00:00<00:00, 594601.19it/s]

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
idf
# Out:
# {'chiva': 3.0546130545568873,
#  'auckland': 2.4537004733597723,
#  'empiree': 3.0546130545568873,
#  'bridwell': 3.0546130545568873,
#  'zucchinni': 3.0546130545568873,
#  'tinker': 3.0546130545568873,
#  'bruner': 3.0546130545568873,
#  'teeming': 3.0546130545568873,
#  'imitating': 2.211806811322216,
#  'laboriously': 2.75396586586516,
#  'umbilicus': 3.0546130545568873,
#  'uninvited': 2.75396586586516,
#  'dismember': 3.0546130545568873,
#  'circumcised': 2.4537004733597723,
#  'spdcc': 2.5782570766553374,
#  '24pm': 3.0546130545568873,
#  'faraday': 2.75396586586516,
#  'leek': 2.0580462303952816,
#  'elaine': 2.2783724736954567,
#  'molotov': 3.0546130545568873,
#  'depict': 3.0546130545568873,
#  'ordinance': 2.4537004733597723,
#  'mathemagic': 3.0546130545568873,
#  'tam': 3.0546130545568873,
#  'unimaginativeness': 3.0546130545568873,
#  'lbl': 2.211806811322216,
#  '_the_misfortune_cookie': 3.0546130545568873,
#  'fainali': 3.0546130545568873,
#  'objectively': 2.75396586586516,
#  'vitc': 3.0546130545568873,
#  'costanzo': 2.5782570766553374,
#  'partakes': 2.75396586586516,
#  'fowl': 2.154195657426271,
#  'asafoetida': 3.0546130545568873,
#  'zero': 1.3420569591316227,
#  'epg': 3.0546130545568873,
#  'vic': 1.9796242406282818,
#  'sillier': 3.0546130545568873,
#  'surveying': 3.0546130545568873,
#  'teamwork': 2.5782570766553374,
#  'mantley': 2.75396586586516,
#  'brownstone': 3.0546130545568873,
#  'wilkerson': 3.0546130545568873,
#  '44he': 3.0546130545568873,
#  'molesting': 2.4537004733597723,
#  'sophie': 3.0546130545568873,
#  'cheaply': 3.0546130545568873,
#  'ell': 2.3571722577230334,
#  'hunchbacked': 2.5782570766553374,
#  'investing': 2.4537004733597723,
#  'naturopathic': 3.0546130545568873,
#  'rrrriiiiinnnnngggggg': 3.0546130545568873,
#  'newswanger': 3.0546130545568873,
#  'basketball': 1.7012299980669172,
#  'panamanian': 3.0546130545568873,
#  'rsoftp': 3.0546130545568873,
#  'suspiciously': 2.211806811322216,
#  'infiltrates': 2.75396586586516,
#  'squarely': 3.0546130545568873,
#  'maynard': 2.5782570766553374,
#  'teamster': 3.0546130545568873,
#  'dimple': 2.75396586586516,
#  'shoesalesmens': 3.0546130545568873,
#  'soupmacs': 3.0546130545568873,
#  'freshen': 3.0546130545568873,
#  '_kindergarten': 3.0546130545568873,
#  'compliment': 1.7607993116307175,
#  'shuts': 2.3571722577230334,
#  'hurse': 3.0546130545568873,
#  'handmade': 2.4537004733597723,
#  'jellico': 3.0546130545568873,
#  'consumed': 1.6028081301553556,
#  'stared': 1.7012299980669172,
#  'sits': 1.3910086602379275,
#  'colorado': 1.5611759470421318,
#  'barleyell': 3.0546130545568873,
#  'leg': 0.9844757782906017,
#  'crustacean': 2.75396586586516,
#  'phringe': 2.75396586586516,
#  '1332pes': 3.0546130545568873,
#  'pequeno': 3.0546130545568873,
#  '42bis': 3.0546130545568873,
#  'kraxxxxxxxxxx': 3.0546130545568873,
#  'accepted': 1.3054242437620733,
#  'unfindable': 3.0546130545568873,
#  'crawlies': 2.75396586586516,
#  'mabel': 2.4537004733597723,
#  'etymological': 2.4537004733597723,
#  'uxh': 3.0546130545568873,
#  'opportune': 2.75396586586516,
#  'dedicate': 2.75396586586516,
#  'lashed': 2.3571722577230334,
#  'piccilo': 3.0546130545568873,
#  'surpriseingly': 3.0546130545568873,
#  'dwain': 3.0546130545568873,
#  'moines': 2.4537004733597723,
#  'mullins': 2.75396586586516,
#  'belabor': 3.0546130545568873,
#  'tham': 3.0546130545568873,
#  'brunette': 2.3571722577230334,
#  'campes': 3.0546130545568873,
#  'meanest': 2.3571722577230334,
#  'behrs': 3.0546130545568873,
#  'persuader': 3.0546130545568873,
#  'cavort': 3.0546130545568873,
#  'troglodyte': 3.0546130545568873,
#  'lawed': 2.75396586586516,
#  'amilyn': 3.0546130545568873,
#  'airmail': 3.0546130545568873,
#  'buttered': 1.7607993116307175,
#  'morphodites': 3.0546130545568873,
#  'nooner': 2.75396586586516,
#  'austrian': 2.211806811322216,
#  'microscopico': 3.0546130545568873,
#  'den': 1.7607993116307175,
#  'usrobotics': 3.0546130545568873,
#  'complaint': 1.5481846105451076,
#  'dcp': 3.0546130545568873,
#  'blindness': 2.5782570766553374,
#  'shove': 1.8838506290062733,
#  'brass': 1.9134353822230294,
#  'darr': 3.0546130545568873,
#  'unlawfully': 3.0546130545568873,
#  'dalnews': 3.0546130545568873,
#  'ssbl': 3.0546130545568873,
#  'caters': 3.0546130545568873,
#  'disservice': 3.0546130545568873,
#  'squeezins': 3.0546130545568873,
#  'pasttimes': 3.0546130545568873,
#  'hideously': 2.5782570766553374,
#  'inaccessible': 2.3571722577230334,
#  'toronto': 1.7201593034059568,
#  'symbolism': 2.4537004733597723,
#  'egotistical': 2.75396586586516,
#  'legiti': 3.0546130545568873,
#  'snunner': 3.0546130545568873,
#  'constellation': 2.5782570766553374,
#  'hypnotises': 3.0546130545568873,
#  'dogfight': 2.5782570766553374,
#  'erp': 3.0546130545568873,
#  'barbeau': 2.75396586586516,
#  'lense': 2.4537004733597723,
#  'keelynet': 3.0546130545568873,
#  'principle': 1.3498088194274545,
#  'wrapper': 1.9796242406282818,
#  'coverdale': 3.0546130545568873,
#  'spamshaft': 3.0546130545568873,
#  'demonic': 2.3571722577230334,
#  'preformed': 2.75396586586516,
#  'produce': 1.0566950978999377,
#  'nie': 3.0546130545568873,
#  'encrypt': 3.0546130545568873,
#  'fristrated': 3.0546130545568873,
#  'ker': 2.5782570766553374,
#  'role': 1.1910495404525718,
#  'margarita': 2.211806811322216,
#  'tended': 1.8838506290062733,
#  'arive': 2.75396586586516,
#  'neatness': 3.0546130545568873,
#  'sin': 1.5233747984261048,
#  'grammer': 2.5782570766553374,
#  'winked': 2.5782570766553374,
#  'dispenser': 2.103423594470504,
#  'jogging': 2.3571722577230334,
#  'hoodoo': 2.75396586586516,
#  'inaudible': 2.5782570766553374,
#  'neato': 2.75396586586516,
#  'quequette': 2.75396586586516,
#  'welt': 3.0546130545568873,
#  'inforcement': 2.75396586586516,
#  'bullheaded': 2.5782570766553374,
#  'chive': 2.4537004733597723,
#  'fortnight': 2.3571722577230334,
#  'indolence': 3.0546130545568873,
#  'surgin': 3.0546130545568873,
#  'blouse': 2.0580462303952816,
#  'polyunsaturated': 3.0546130545568873,
#  'receptical': 3.0546130545568873,
#  'elisha': 2.4537004733597723,
#  'dartmouth': 2.154195657426271,
#  'amarillo': 2.75396586586516,
#  'dipper': 2.75396586586516,
#  'admonished': 3.0546130545568873,
#  'freebie': 2.2783724736954567,
#  'dispersed': 2.4537004733597723,
#  'slit': 1.9452412653245341,
#  'raz': 2.75396586586516,
#  'pectic': 3.0546130545568873,
#  'l8ter': 3.0546130545568873,
#  'hilt': 2.3571722577230334,
#  'mobbedwithwhatdoesibmstandforanswers': 3.0546130545568873,
#  'salutation': 2.4537004733597723,
#  'nensei': 3.0546130545568873,
#  's1101': 3.0546130545568873,
#  'kubla': 3.0546130545568873,
#  'cornflour': 3.0546130545568873,
#  'brocklehurst': 3.0546130545568873,
#  'shinobugaoka': 3.0546130545568873,
#  'patsy': 2.154195657426271,
#  'lomtick': 3.0546130545568873,
#  'yeckate': 3.0546130545568873,
#  'drum': 1.649110087992778,
#  'foamfollower': 3.0546130545568873,
#  'masato': 3.0546130545568873,
#  'restraint': 2.154195657426271,
#  'riotous': 3.0546130545568873,
#  'enforcement': 1.8302489189753377,
#  'comanski': 3.0546130545568873,
#  'volvo': 2.0170333392987803,
#  'paco': 3.0546130545568873,
#  'xx': 1.8838506290062733,
#  'emanates': 2.75396586586516,
#  'avast': 3.0546130545568873,
#  'lynched': 3.0546130545568873,
#  'altmode': 3.0546130545568873,
#  'bak': 2.5782570766553374,
#  'hywell': 2.75396586586516,
#  'rocketman': 3.0546130545568873,
#  'peruvian': 3.0546130545568873,
#  'fff': 3.0546130545568873,
#  'clack': 3.0546130545568873,
#  'athe': 3.0546130545568873,
#  'tx': 1.8058028185264856,
#  '__divorced': 3.0546130545568873,
#  'yasmilov': 3.0546130545568873,
#  'ity': 2.5782570766553374,
#  'maquire': 3.0546130545568873,
#  'entymologists': 2.75396586586516,
#  'sensical': 3.0546130545568873,
#  'tonsillectomy': 3.0546130545568873,
#  '1500hz': 3.0546130545568873,
#  'v2': 2.3571722577230334,
#  'ecn': 3.0546130545568873,
#  'parole': 2.3571722577230334,
#  'privileged': 2.4537004733597723,
#  'epilogue': 2.2783724736954567,
#  'economically': 2.5782570766553374,
#  'dyall': 3.0546130545568873,
#  'samson': 2.5782570766553374,
#  'demonstrator': 2.75396586586516,
#  'kneel': 2.3571722577230334,
#  'vasquez': 3.0546130545568873,
#  'conducive': 2.75396586586516,
#  'unzip': 3.0546130545568873,
#  'reunited': 2.5782570766553374,
#  'evaporated': 2.154195657426271,
#  'forgives': 2.75396586586516,
#  'bumpy': 3.0546130545568873,
#  'ignorante': 3.0546130545568873,
#  'affidavit': 2.75396586586516,
#  'borrowed': 1.9452412653245341,
#  'jimcat': 3.0546130545568873,
#  'sit': 0.8889680148357232,
#  'minivan': 3.0546130545568873,
#  'od': 2.2783724736954567,
#  'zodiac': 3.0546130545568873,
#  'maupin': 3.0546130545568873,
#  'gtsi': 3.0546130545568873,
#  'harriet': 2.4537004733597723,
#  'fait': 2.3571722577230334,
#  'ersatz': 3.0546130545568873,
#  'chubbies': 3.0546130545568873,
#  'steeple': 3.0546130545568873,
#  'volkswagon': 2.4537004733597723,
#  'flattery': 2.5782570766553374,
#  'blew': 1.5233747984261048,
#  'sfu': 2.5782570766553374,
#  'snodgrass': 2.75396586586516,
#  'whimpering': 2.3571722577230334,
#  'inning': 2.2783724736954567,
#  'staring': 1.4778630046555723,
#  'balun': 3.0546130545568873,
#  'storre': 3.0546130545568873,
#  'compiling': 2.3571722577230334,
#  'times_': 3.0546130545568873,
#  '4x3': 3.0546130545568873,
#  'steffey': 3.0546130545568873,
#  'acerebral': 3.0546130545568873,
#  'demonews': 3.0546130545568873,
#  'fountainhead': 3.0546130545568873,
#  'haze': 2.0170333392987803,
#  'psilocybin': 3.0546130545568873,
#  'bimbicarb': 3.0546130545568873,
#  'intent': 1.739986514085793,
#  'culinary': 2.0170333392987803,
#  'eleventh': 2.4537004733597723,
#  'wanton': 2.3571722577230334,
#  'felsenstein': 3.0546130545568873,
#  'toasting': 2.75396586586516,
#  'addicted': 1.8838506290062733,
#  'guile': 2.75396586586516,
#  'mondal': 3.0546130545568873,
#  'kingly': 3.0546130545568873,
#  'outnumber': 3.0546130545568873,
#  'shredder': 2.5782570766553374,
#  'realted': 3.0546130545568873,
#  'sojourn': 2.75396586586516,
#  'platten': 3.0546130545568873,
#  'reloaded': 2.5782570766553374,
#  'laval': 3.0546130545568873,
#  'sulphate': 3.0546130545568873,
#  'toujutsu': 3.0546130545568873,
#  'vieux': 2.75396586586516,
#  'fetching': 3.0546130545568873,
#  'pours': 2.103423594470504,
#  'testiculos': 3.0546130545568873,
#  'centre': 1.7201593034059568,
#  'capt': 2.4537004733597723,
#  'untouchable': 2.5782570766553374,
#  'bisquet': 3.0546130545568873,
#  'robber': 1.7607993116307175,
#  'do0d': 3.0546130545568873,
#  'wimpie': 3.0546130545568873,
#  'cockrum': 3.0546130545568873,
#  'caffiene': 2.75396586586516,
#  'conte': 3.0546130545568873,
#  'dissappeared': 2.5782570766553374,
#  'evel': 3.0546130545568873,
#  'dweeb': 2.5782570766553374,
#  'obver': 3.0546130545568873,
#  'demonically': 3.0546130545568873,
#  'sortie': 3.0546130545568873,
#  's1106': 3.0546130545568873,
#  'schneck': 3.0546130545568873,
#  '100mhz': 3.0546130545568873,
#  'guenevere': 3.0546130545568873,
#  'breadth': 2.75396586586516,
#  'llbe': 3.0546130545568873,
#  '7am': 3.0546130545568873,
#  'shoulderlike': 3.0546130545568873,
#  'libation': 3.0546130545568873,
#  'longevity': 2.5782570766553374,
#  'raced': 2.103423594470504,
#  'retina': 2.4537004733597723,
#  'petersen': 3.0546130545568873,
#  'growl': 2.5782570766553374,
#  'prounciations': 3.0546130545568873,
#  'translated': 1.7201593034059568,
#  'pinstriped': 2.75396586586516,
#  'wharton': 2.75396586586516,
#  'balancee': 2.75396586586516,
#  'laundry': 1.7201593034059568,
#  'davidbedno': 3.0546130545568873,
#  'eel': 2.0580462303952816,
#  'opion': 3.0546130545568873,
#  'prompt': 1.6028081301553556,
#  'sherlock': 2.103423594470504,
#  'brocali': 3.0546130545568873,
#  'mog': 2.75396586586516,
#  'doppelgaenger': 3.0546130545568873,
#  'araby': 3.0546130545568873,
#  'neal': 2.103423594470504,
#  'introspection': 2.5782570766553374,
#  'untie': 2.75396586586516,
#  'akers': 2.75396586586516,
#  'punishes': 2.75396586586516,
#  'slob': 2.4537004733597723,
#  'morning': 0.8428062432346719,
#  'phlange': 3.0546130545568873,
#  'eructed': 3.0546130545568873,
#  'upi': 2.2783724736954567,
#  'ltc': 2.75396586586516,
#  'atrociously': 3.0546130545568873,
#  'rayburn': 3.0546130545568873,
#  'degrading': 2.75396586586516,
#  'bloomingdale': 2.75396586586516,
#  'pervs': 3.0546130545568873,
#  'since': 0.6337922374442522,
#  'yasmine': 3.0546130545568873,
#  'borkow': 3.0546130545568873,
#  'podunk': 3.0546130545568873,
#  'tekig5': 3.0546130545568873,
#  'soupy': 2.4537004733597723,
#  'nutshell': 2.4537004733597723,
#  'bairacli': 3.0546130545568873,
#  'zippo': 2.4537004733597723,
#  'condemns': 3.0546130545568873,
#  'hyperreflexia': 3.0546130545568873,
#  'megger': 3.0546130545568873,
#  'toldim': 3.0546130545568873,
#  'justis': 3.0546130545568873,
#  'zdap194': 3.0546130545568873,
#  'levitation': 3.0546130545568873,
#  'ichthyosis': 3.0546130545568873,
#  'cosell': 2.75396586586516,
#  'nbo': 3.0546130545568873,
#  'qbed': 3.0546130545568873,
#  'grabbed': 1.5745912864795968,
#  'abbey': 2.75396586586516,
#  'etiquitte': 3.0546130545568873,
#  'wrestler': 2.2783724736954567,
#  'transience': 3.0546130545568873,
#  'swanson': 2.2783724736954567,
#  'schultz': 2.3571722577230334,
#  'dasilva': 3.0546130545568873,
#  'lifted': 1.6831221172401434,
#  'kernighan': 3.0546130545568873,
#  'shhh': 2.5782570766553374,
#  'wolfie': 3.0546130545568873,
#  'paroxisms': 3.0546130545568873,
#  'ligature': 3.0546130545568873,
#  'perl': 2.5782570766553374,
#  'ghorban': 2.4537004733597723,
#  'pepys': 3.0546130545568873,
#  'limit': 1.2783906301988102,
#  'hyperglucocemia': 3.0546130545568873,
#  'recorerder': 3.0546130545568873,
#  'mk': 2.75396586586516,
#  'oto': 3.0546130545568873,
#  'getwell': 3.0546130545568873,
#  'marcy': 2.75396586586516,
#  'calavicci': 3.0546130545568873,
#  'flinched': 2.75396586586516,
#  'brightly': 1.85620004603236,
#  'carello': 3.0546130545568873,
#  'ohstvma': 3.0546130545568873,
#  'riskier': 3.0546130545568873,
#  'whinging': 3.0546130545568873,
#  'ndl': 3.0546130545568873,
#  'wheatell': 3.0546130545568873,
#  'albuquerque': 2.5782570766553374,
#  'essex': 2.75396586586516,
#  'goddamit': 2.2783724736954567,
#  'delphi': 2.211806811322216,
#  'dyke': 1.9796242406282818,
#  'unpasteurized': 2.75396586586516,
#  'clearinghouse': 3.0546130545568873,
#  'rusty': 1.7607993116307175,
#  'underestimate': 2.3571722577230334,
#  'thelambtresspasserfuckerfuckedgenesisrevelationmyassbarayannef': 3.0546130545568873,
#  'clandt': 2.75396586586516,
#  'winke': 3.0546130545568873,
#  'umbc1': 2.75396586586516,
#  'millhollin': 3.0546130545568873,
#  'psychoshocker': 3.0546130545568873,
#  'jug': 1.8058028185264856,
#  'amarilla': 3.0546130545568873,
#  'umbilical': 2.5782570766553374,
#  'atanud8j4ii': 3.0546130545568873,
#  'okie': 2.75396586586516,
#  '128a': 3.0546130545568873,
#  'disagreeing': 3.0546130545568873,
#  'shin': 1.9796242406282818,
#  'thish': 2.75396586586516,
#  'rigney': 3.0546130545568873,
#  'jcae': 3.0546130545568873,
#  'ney': 2.4537004733597723,
#  'pierre': 2.2783724736954567,
#  'padre': 2.5782570766553374,
#  'dym': 3.0546130545568873,
#  'gewurztraminer': 3.0546130545568873,
#  'drew': 1.4999841376791665,
#  'pleasing': 2.211806811322216,
#  'crunchies': 2.75396586586516,
#  'sacrifice': 1.6831221172401434,
#  'retin': 3.0546130545568873,
#  'mackerel': 3.0546130545568873,
#  'dec21': 3.0546130545568873,
#  'frogwoman': 3.0546130545568873,
#  'hiking': 2.4537004733597723,
#  'approching': 3.0546130545568873,
#  'dulce': 3.0546130545568873,
#  'cavalier': 2.3571722577230334,
#  'repellers': 3.0546130545568873,
#  'viper': 3.0546130545568873,
#  'annie': 1.85620004603236,
#  'farley': 2.75396586586516,
#  'keymah': 3.0546130545568873,
#  'kelpy': 3.0546130545568873,
#  'asner': 2.5782570766553374,
#  'aaaiiieeeeeee': 3.0546130545568873,
#  'caravaggio': 3.0546130545568873,
#  'ipad': 3.0546130545568873,
#  'garnishee': 3.0546130545568873,
#  'gurgly': 3.0546130545568873,
#  'revolution_': 3.0546130545568873,
#  'universitet': 3.0546130545568873,
#  'santrginus': 3.0546130545568873,
#  'belives': 3.0546130545568873,
#  'constructed': 2.0170333392987803,
#  'inured': 2.75396586586516,
#  'moro': 3.0546130545568873,
#  'imphobia': 3.0546130545568873,
#  'continuation': 2.2783724736954567,
#  'imbeded': 3.0546130545568873,
#  'daisuke': 3.0546130545568873,
#  'saddest': 2.75396586586516,
#  'mhnadel': 3.0546130545568873,
#  'docked': 2.75396586586516,
#  'lin': 1.9452412653245341,
#  'kennel': 2.3571722577230334,
#  'squawk': 2.75396586586516,
#  '07094_____________': 3.0546130545568873,
#  'charming': 1.9134353822230294,
#  'tonton': 3.0546130545568873,
#  'mcgonagle': 2.5782570766553374,
#  'overlook': 2.5782570766553374,
#  'crewed': 3.0546130545568873,
#  'cav': 2.4537004733597723,
#  'dadoscope': 3.0546130545568873,
#  'vince': 2.211806811322216,
#  'clever': 1.4672380207875668,
#  'amputated': 2.75396586586516,
#  'churchgoer': 3.0546130545568873,
#  'interconnect': 2.75396586586516,
#  'metrocruiser': 3.0546130545568873,
#  'haden': 3.0546130545568873,
#  'outgas': 3.0546130545568873,
#  'hellbent': 3.0546130545568873,
#  'terminate': 2.4537004733597723,
#  'amato': 2.75396586586516,
#  'annually': 2.5782570766553374,
#  'mcnaught': 3.0546130545568873,
#  'crummy': 2.5782570766553374,
#  'collie': 2.75396586586516,
#  'alger': 3.0546130545568873,
#  'epples': 3.0546130545568873,
#  'cool': 0.8547679519522473,
#  'superstitious': 2.5782570766553374,
#  'learing': 3.0546130545568873,
#  'practically': 1.6176741883963546,
#  'subset': 2.75396586586516,
#  'discard': 1.5884584600087859,
#  'stagering': 3.0546130545568873,
#  'snotface': 3.0546130545568873,
#  '0i': 3.0546130545568873,
#  'mcardle': 2.75396586586516,
#  'tagged': 2.4537004733597723,
#  'curtail': 3.0546130545568873,
#  '50h': 3.0546130545568873,
#  'veddy': 2.75396586586516,
#  'displayest': 3.0546130545568873,
#  'cci': 3.0546130545568873,
#  'scrotum': 2.2783724736954567,
#  'bursar': 3.0546130545568873,
#  'outshined': 2.5782570766553374,
#  'mikvaot': 3.0546130545568873,
#  'combat': 1.5745912864795968,
#  'carli': 3.0546130545568873,
#  'dasy': 3.0546130545568873,
#  'disorder': 1.5884584600087859,
#  'uptime': 2.5782570766553374,
#  'enshrined': 3.0546130545568873,
#  'absolutely': 1.196294645143968,
#  'herpe': 3.0546130545568873,
#  'knievel': 3.0546130545568873,
#  'bushey': 3.0546130545568873,
#  'munch': 2.4537004733597723,
#  'exclaim': 2.3571722577230334,
#  'innocecnt': 3.0546130545568873,
#  'merp': 3.0546130545568873,
#  'fontaine': 3.0546130545568873,
#  'goddaughter': 3.0546130545568873,
#  'asme': 3.0546130545568873,
#  'knut': 3.0546130545568873,
#  'forequarter': 2.75396586586516,
#  'saber': 2.4537004733597723,
#  'pub': 1.5745912864795968,
#  'nandina': 3.0546130545568873,
#  '289b2457': 3.0546130545568873,
#  'sysmptoms': 3.0546130545568873,
#  'parisot': 3.0546130545568873,
#  'weaver': 2.154195657426271,
#  'overrunning': 3.0546130545568873,
#  'healing': 1.9134353822230294,
#  'exponent': 2.5782570766553374,
#  'minaret': 3.0546130545568873,
#  'clampett': 2.5782570766553374,
#  'withe': 3.0546130545568873,
#  'surrounsd': 3.0546130545568873,
#  'bewildered': 2.154195657426271,
#  'passaic': 3.0546130545568873,
#  'ooooh': 3.0546130545568873,
#  'tar': 1.9796242406282818,
#  'newz': 3.0546130545568873,
#  'exhaling': 3.0546130545568873,
#  'mistrust': 2.75396586586516,
#  'kryptonne': 3.0546130545568873,
#  'discussion': 1.291674491782583,
#  'ear': 1.0530784434834197,
#  'murphy': 1.5481846105451076,
#  'chopd': 3.0546130545568873,
#  'radka': 2.75396586586516,
#  '70mg': 3.0546130545568873,
#  'intrested': 2.75396586586516,
#  'mixture': 1.0677654411112931,
#  'glassblower': 3.0546130545568873,
#  'intap': 3.0546130545568873,
#  'contac': 3.0546130545568873,
#  'nilrem': 3.0546130545568873,
#  'bullbars': 3.0546130545568873,
#  'learnin': 2.5782570766553374,
#  'shelving': 3.0546130545568873,
#  'blavatsky': 2.5782570766553374,
#  'lumbar': 3.0546130545568873,
#  'sequential': 2.75396586586516,
#  'tautology': 2.75396586586516,
#  'facon': 3.0546130545568873,
#  'booting': 2.5782570766553374,
#  'quinine': 3.0546130545568873,
#  'hosted': 2.211806811322216,
#  'second': 0.6367238298003757,
#  'unresolvable': 3.0546130545568873,
#  'madeline': 3.0546130545568873,
#  'mitnick': 2.75396586586516,
#  'perverted': 2.211806811322216,
#  'candle': 1.649110087992778,
#  'bundt': 2.5782570766553374,
#  'obituary': 3.0546130545568873,
#  'babosa': 3.0546130545568873,
#  'final': 0.96708315379955,
#  'calmly': 1.8058028185264856,
#  'stringfellow': 3.0546130545568873,
#  'cadenza': 3.0546130545568873,
#  'partly': 1.782698878134364,
#  'hobbled': 3.0546130545568873,
#  'thixteen': 3.0546130545568873,
#  'cuticle': 2.5782570766553374,
#  'yokohama': 3.0546130545568873,
#  'kaleidoscopic': 3.0546130545568873,
#  'sentiency': 3.0546130545568873,
#  'airange': 3.0546130545568873,
#  'chronical': 3.0546130545568873,
#  'introduces': 1.9452412653245341,
#  'regulates': 3.0546130545568873,
#  'blsplorkt': 3.0546130545568873,
#  'magma': 3.0546130545568873,
#  'agentorange': 3.0546130545568873,
#  'jedzia': 3.0546130545568873,
#  'phuck': 2.75396586586516,
#  'pace': 1.8302489189753377,
#  'pas': 0.993505116925213,
#  'maser': 2.75396586586516,
#  'stc': 2.5782570766553374,
#  'princeton': 2.0170333392987803,
#  'guthrie': 3.0546130545568873,
#  'boe': 3.0546130545568873,
#  'goff': 3.0546130545568873,
#  'outta': 2.103423594470504,
#  'thresher': 3.0546130545568873,
#  'kr': 2.5782570766553374,
#  'jagger': 2.2783724736954567,
#  'placemat': 2.75396586586516,
#  'majorbbs': 3.0546130545568873,
#  'palmfuls': 3.0546130545568873,
#  'tricicle': 3.0546130545568873,
#  'charlotte': 2.103423594470504,
#  'likelyhood': 3.0546130545568873,
#  'bunny': 1.633094225067931,
#  'cahrm': 3.0546130545568873,
#  'mosfet': 2.75396586586516,
#  'flizza': 3.0546130545568873,
#  'recitates': 3.0546130545568873,
#  'headquartered': 2.5782570766553374,
#  'bosser': 3.0546130545568873,
#  'chlorate': 3.0546130545568873,
#  'span': 1.9452412653245341,
#  'rban': 3.0546130545568873,
#  'invisibles': 2.75396586586516,
#  '12bd': 3.0546130545568873,
#  'gorbachef': 3.0546130545568873,
#  'yel': 2.75396586586516,
#  'feelgood': 2.5782570766553374,
#  'nik': 2.5782570766553374,
#  'line13': 3.0546130545568873,
#  'rosie': 2.3571722577230334,
#  'fortenberry': 3.0546130545568873,
#  'rahway': 3.0546130545568873,
#  'smulrine': 3.0546130545568873,
#  'jamming': 2.103423594470504,
#  'buzz_': 3.0546130545568873,
#  'earwig': 3.0546130545568873,
#  'attrition': 3.0546130545568873,
#  'al1040': 3.0546130545568873,
#  'gedankesexperimenten': 2.75396586586516,
#  'viscerally': 3.0546130545568873,
#  'ttma': 3.0546130545568873,
#  'caraway': 2.2783724736954567,
#  'deadhead': 2.75396586586516,
#  'conspirator': 2.75396586586516,
#  'readjusted': 2.75396586586516,
#  'poindexter': 1.2849762157859024,
#  'roger': 1.4467885762098545,
#  'karramesh': 3.0546130545568873,
#  'ernest': 2.211806811322216,
#  'corduroy': 2.5782570766553374,
#  'wasser': 3.0546130545568873,
#  'hitchhiker_': 3.0546130545568873,
#  'disparate': 3.0546130545568873,
#  'goldner': 2.75396586586516,
#  'theier': 3.0546130545568873,
#  'griffith': 2.0580462303952816,
#  'karma': 2.0580462303952816,
#  'pikrone': 3.0546130545568873,
#  'opinionated': 2.75396586586516,
#  'pandora': 2.5782570766553374,
#  'yume': 3.0546130545568873,
#  'asthma': 3.0546130545568873,
#  'dirt': 1.5481846105451076,
#  'prophetic': 3.0546130545568873,
#  'pinkie': 2.75396586586516,
#  'blunder': 2.3571722577230334,
#  'bellowed': 2.211806811322216,
#  'hamel': 3.0546130545568873,
#  'nau': 2.75396586586516,
#  'lu': 3.0546130545568873,
#  'clawing': 2.75396586586516,
#  'twee': 3.0546130545568873,
#  'curvilinear': 2.5782570766553374,
#  'filter': 1.7607993116307175,
#  'prank': 1.6831221172401434,
#  'sbe': 2.75396586586516,
#  'leftover': 1.8302489189753377,
#  'eagerness': 3.0546130545568873,
#  'relocating': 3.0546130545568873,
#  'corroboree': 3.0546130545568873,
#  'obrist': 3.0546130545568873,
#  'unlink': 3.0546130545568873,
#  'recruited': 2.154195657426271,
#  'crknecht': 3.0546130545568873,
#  'fudgies': 3.0546130545568873,
#  'evilminded': 3.0546130545568873,
#  'vanity': 1.9452412653245341,
#  'crowning': 2.5782570766553374,
#  '__doesn': 2.75396586586516,
#  'escrow': 3.0546130545568873,
#  'eirp': 3.0546130545568873,
#  'valentine': 2.0170333392987803,
#  'dp': 2.4537004733597723,
#  'jukebox': 2.4537004733597723,
#  'fourier': 2.211806811322216,
#  'rothstein': 3.0546130545568873,
#  'york': 1.0494974015681422,
#  'snailmail': 3.0546130545568873,
#  'croix': 3.0546130545568873,
#  'franccsco': 3.0546130545568873,
#  'meyers': 2.5782570766553374,
#  'parsely': 3.0546130545568873,
#  'tetraflouride': 3.0546130545568873,
#  'overlap': 2.5782570766553374,
#  'pssst': 3.0546130545568873,
#  'thawing': 3.0546130545568873,
#  'screaming': 1.0459513287615734,
#  'vint': 2.75396586586516,
#  'rediscovered': 3.0546130545568873,
#  'diffract': 3.0546130545568873,
#  'whisk': 2.3571722577230334,
#  'pravda': 3.0546130545568873,
#  'domicile': 2.5782570766553374,
#  'kasdarf': 2.75396586586516,
#  'lga': 3.0546130545568873,
#  'atl': 3.0546130545568873,
#  'echinacea': 3.0546130545568873,
#  'fdhd': 3.0546130545568873,
#  'ioioioioioioioioioioioio': 2.75396586586516,
#  'shingle': 2.2783724736954567,
#  'delightfully': 3.0546130545568873,
#  'potage': 3.0546130545568873,
#  'nebulous': 3.0546130545568873,
#  'anahiem': 3.0546130545568873,
#  'commuting': 2.4537004733597723,
#  'bethe': 2.3571722577230334,
#  'deslar': 3.0546130545568873,
#  'surfin': 3.0546130545568873,
#  'pixy': 3.0546130545568873,
#  'defends': 2.75396586586516,
#  'haysack': 3.0546130545568873,
#  'desiring': 3.0546130545568873,
#  'furnace': 2.2783724736954567,
#  'marinaade': 3.0546130545568873,
#  'traynor': 2.75396586586516,
#  'berruga': 3.0546130545568873,
#  'polling': 2.75396586586516,
#  'ceremony': 1.6176741883963546,
#  'ctrical': 3.0546130545568873,
#  'berghev': 3.0546130545568873,
#  'hermie': 3.0546130545568873,
#  'nosed': 2.0580462303952816,
#  'loyalty': 1.9452412653245341,
#  'thickened': 1.9134353822230294,
#  '45mg': 3.0546130545568873,
#  'preserv': 3.0546130545568873,
#  '9gn5f': 3.0546130545568873,
#  'aquarius': 2.0170333392987803,
#  'bride': 1.5884584600087859,
#  'ironwork': 3.0546130545568873,
#  'ibe': 3.0546130545568873,
#  'multiline': 3.0546130545568873,
#  'lowliest': 3.0546130545568873,
#  'boardwatch': 2.75396586586516,
#  'biggie': 2.2783724736954567,
#  'mcarty': 3.0546130545568873,
#  'grouchy': 2.75396586586516,
#  'pkt': 3.0546130545568873,
#  'sociable': 2.5782570766553374,
#  'consul': 2.75396586586516,
#  'bg': 3.0546130545568873,
#  'flippantly': 2.4537004733597723,
#  'giant': 1.2655434614104368,
#  'cancellation': 2.2783724736954567,
#  'usadvertising': 3.0546130545568873,
#  'longmans': 3.0546130545568873,
#  'flamenco': 3.0546130545568873,
#  'souse': 3.0546130545568873,
#  'conferencing': 3.0546130545568873,
#  'lindley': 3.0546130545568873,
#  'porgie': 3.0546130545568873,
#  'fausto': 3.0546130545568873,
#  'sprite': 2.4537004733597723,
#  'proclaiming': 2.5782570766553374,
#  'automation': 2.75396586586516,
#  'maneuver': 2.0580462303952816,
#  'lends': 2.4537004733597723,
#  'miniskirt': 3.0546130545568873,
#  'speculation': 1.326993827612491,
#  'kraftwerk': 2.5782570766553374,
#  'brennert': 2.75396586586516,
#  'balaban': 3.0546130545568873,
#  'sentenced': 1.8838506290062733,
#  'coffeehouse': 2.75396586586516,
#  'hollis': 2.3571722577230334,
#  'storeroom': 2.2783724736954567,
#  'strike': 1.2351675873255878,
#  'fulbright': 2.75396586586516,
#  'dlnichol': 3.0546130545568873,
#  'harley': 2.211806811322216,
#  'purlie': 3.0546130545568873,
#  'hexun': 3.0546130545568873,
#  'topaz': 2.5782570766553374,
#  'spicy': 1.633094225067931,
#  'gekko': 3.0546130545568873,
#  'sunday': 1.2655434614104368,
#  'eighteenth': 2.211806811322216,
#  'affecting': 2.154195657426271,
#  'xe': 2.75396586586516,
#  'smurf': 2.103423594470504,
#  'convinced': 1.326993827612491,
#  'smack': 1.8302489189753377,
#  'loaned': 2.5782570766553374,
#  'wetstone': 3.0546130545568873,
#  'x544': 3.0546130545568873,
#  'nepalm': 3.0546130545568873,
#  'pestilence': 2.5782570766553374,
#  'sylvester': 2.154195657426271,
#  'craig': 1.7201593034059568,
#  'anorexia': 2.4537004733597723,
#  'loudened': 3.0546130545568873,
#  'adelaide': 3.0546130545568873,
#  'providentially': 3.0546130545568873,
#  'studying': 1.7607993116307175,
#  'trinket': 2.4537004733597723,
#  'orokaiva': 3.0546130545568873,
#  'christina': 2.5782570766553374,
#  '13th': 1.9452412653245341,
#  'eluded': 3.0546130545568873,
#  'bonded': 3.0546130545568873,
#  'malchick': 3.0546130545568873,
#  'crab': 1.782698878134364,
#  'infantry': 3.0546130545568873,
#  'tommie': 3.0546130545568873,
#  'cosiie': 3.0546130545568873,
#  'unintentionnaly': 3.0546130545568873,
#  'remarque': 3.0546130545568873,
#  'adrenalin': 2.5782570766553374,
#  'roux': 2.4537004733597723,
#  'ellery': 3.0546130545568873,
#  'sucking': 1.8302489189753377,
#  'anchored': 3.0546130545568873,
#  'grandest': 2.75396586586516,
#  'iambic': 2.75396586586516,
#  'basset': 3.0546130545568873,
#  'strack': 3.0546130545568873,
#  'hoven': 3.0546130545568873,
#  'telly': 2.5782570766553374,
#  'battered': 2.154195657426271,
#  'unwed': 3.0546130545568873,
#  '____________________________________________________________': 3.0546130545568873,
#  'continuity': 2.211806811322216,
#  'pedestrian': 2.0580462303952816,
#  'frome': 3.0546130545568873,
#  'c110': 3.0546130545568873,
#  '3gb': 3.0546130545568873,
#  'whole': 0.6968313708385375,
#  'hoek': 2.3571722577230334,
#  '3pm': 3.0546130545568873,
#  'nightswimming': 2.5782570766553374,
#  'poincare': 3.0546130545568873,
#  'maneuvering': 2.2783724736954567,
#  'scholarly': 2.75396586586516,
#  'sigcat': 3.0546130545568873,
#  'disarrayed': 2.75396586586516,
#  'approaching': 1.5884584600087859,
#  'sunybcs': 3.0546130545568873,
#  'intermittently': 2.3571722577230334,
#  'lori': 2.211806811322216,
#  'causeway': 3.0546130545568873,
#  'illegitimately': 3.0546130545568873,
#  'steinfeld': 3.0546130545568873,
#  'workmanship': 2.5782570766553374,
#  'fireside': 2.4537004733597723,
#  'lovey': 3.0546130545568873,
#  'jogger': 2.4537004733597723,
#  'tooling': 2.75396586586516,
#  'prometheus': 2.3571722577230334,
#  'bochner': 2.75396586586516,
#  'naaaah': 3.0546130545568873,
#  '601b': 3.0546130545568873,
#  'ancestry': 2.5782570766553374,
#  'indicating': 1.9796242406282818,
#  'eskimo': 2.3571722577230334,
#  'alligator': 2.154195657426271,
#  'extinguisher': 2.4537004733597723,
#  'digitiz': 3.0546130545568873,
#  'wallbanger': 2.75396586586516,
#  'browsed': 3.0546130545568873,
#  'neutering': 3.0546130545568873,
#  'herblock': 3.0546130545568873,
#  'hotel': 1.207005670893413,
#  'nrc': 2.4537004733597723,
#  'computability': 3.0546130545568873,
#  'highball': 2.2783724736954567,
#  'archived': 2.5782570766553374,
#  'ghanoush': 3.0546130545568873,
#  'ignored': 1.45688424019186,
#  'shortstack': 3.0546130545568873,
#  'sensory': 2.5782570766553374,
#  'ence': 3.0546130545568873,
#  'ambifacient': 3.0546130545568873,
#  'pyke': 3.0546130545568873,
#  'gregory': 1.633094225067931,
#  'moonlit': 2.4537004733597723,
#  'aba': 3.0546130545568873,
#  'e_': 3.0546130545568873,
#  'vicinity': 2.103423594470504,
#  'getty': 2.75396586586516,
#  'mantee': 2.75396586586516,
#  'atb': 3.0546130545568873,
#  'writes': 1.3196721057200391,
#  'lorne': 2.75396586586516,
#  'ugh': 2.0580462303952816,
#  'metabolically': 3.0546130545568873,
#  'mcginty': 3.0546130545568873,
#  'conjoined': 3.0546130545568873,
#  'shooter': 2.2783724736954567,
#  'oddest': 2.5782570766553374,
#  'ootake': 3.0546130545568873,
#  'speeching': 2.75396586586516,
#  'beaming': 2.5782570766553374,
#  'wck': 3.0546130545568873,
#  'infield': 2.3571722577230334,
#  'refrigerating': 3.0546130545568873,
#  'escape': 1.1157167091273055,
#  'r2': 2.4537004733597723,
#  'sprint': 2.211806811322216,
#  'marcovici': 3.0546130545568873,
#  'falvey': 3.0546130545568873,
#  'munson': 3.0546130545568873,
#  'mislead': 3.0546130545568873,
#  'mopheds': 3.0546130545568873,
#  'victor': 1.7012299980669172,
#  'guiness': 2.5782570766553374,
#  'reformer': 3.0546130545568873,
#  'modine': 3.0546130545568873,
#  'persimmon': 3.0546130545568873,
#  'janice': 2.3571722577230334,
#  'tyrant': 2.0580462303952816,
#  'maui': 3.0546130545568873,
#  'kramden': 3.0546130545568873,
#  'interconnected': 3.0546130545568873,
#  'hesitation': 2.211806811322216,
#  'jsd': 3.0546130545568873,
#  'capsaicin': 3.0546130545568873,
#  'sharga': 3.0546130545568873,
#  'archimedeans': 3.0546130545568873,
#  'unseeing': 3.0546130545568873,
#  'british': 1.2655434614104368,
#  '3ɪa': 3.0546130545568873,
#  'waltrip': 3.0546130545568873,
#  'apporoach': 3.0546130545568873,
#  'synagogue': 2.4537004733597723,
#  'laurentpublicenemynwathed': 3.0546130545568873,
#  'hopelessness': 2.75396586586516,
#  'bleu': 2.4537004733597723,
#  'valium': 2.75396586586516,
#  'curt': 2.3571722577230334,
#  'saving': 1.3657815262889645,
#  'filo': 2.75396586586516,
#  'jaeck': 2.75396586586516,
#  'pahr': 3.0546130545568873,
#  'motherfucken': 2.75396586586516,
#  'diantes': 3.0546130545568873,
#  'conquering': 3.0546130545568873,
#  'lru': 3.0546130545568873,
#  'bloodthirsty': 2.75396586586516,
#  'afterlife': 2.2783724736954567,
#  'augxww': 3.0546130545568873,
#  'distorted': 2.0580462303952816,
#  'hyperdrive': 3.0546130545568873,
#  'smurfurr': 3.0546130545568873,
#  'jostled': 3.0546130545568873,
#  ...}

# %%
doc={}
for x in range(1):
  print("")
for j in tqdm(range(len(dict))):
  term={}
  for i in (voc):
    for x in range(1):
      print("")
    if (j+1) not in list(p_ind[i][1].keys()):
      counter=0
    else:
      counter=len(p_ind[i][1][j+1])
      for x in range(1):
        print("")
    term[i]=counter
  doc[b[j]]=term
for x in range(1):
  print("")
# Out:
# 100%|██████████| 1133/1133 [02:21<00:00,  7.98it/s]

# %%
for j in range(len(dict)):
    if (j+1) not in list(p_ind[i][1].keys()):
      count=0
    else:
      count=(len(p_ind[i][1][j+1])/totalsum[b[j]])
