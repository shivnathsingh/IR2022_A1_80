# %%
import glob
import os
import string
import nltk
import re
import pandas as pd
import numpy as np

# %%
P="/content/drive/MyDrive/Humor,Hist,Media,Food/*"

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
s=stopwords.words('english')

# %%
a=[]
for i in glob.glob(P):
  a.append("/content/drive/MyDrive/Humor,Hist,Media,Food/"+os.path.basename(i))

# %%
len(a)
# Out:
# 1133

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
from tqdm import tqdm

# %%
import os
import glob
import pandas as pd
import numpy as np
import nltk
import re
nltk.download('stopwords')
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 

import nltk
nltk.download('stopwords')  


nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import gensim
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stop_words = set(stopwords.words('english'));
p_ind={}
dict=[]
e=[]
voc=[]
docid=1
for i in tqdm(range(len(a))):
  with open(a[i],encoding="utf8",errors='ignore') as file:
    c=[]
    text =file.read()
    text=text.lower()   #to convert in to lower case 
    text=text.strip()
    text = re.sub(r'[^\w\s]', ' ', text)  # To remove puntuation
    word_tokens = word_tokenize(text)   # toknization 
    final_tokens=[w for w in word_tokens if w not in stop_words] # stopword remove
    final_tokens=[ lemmatizer.lemmatize(word) for word in final_tokens]
    final_tokens = [x for x in final_tokens if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
    final_tokens=set(final_tokens)
    for term in final_tokens:
      if term not in c:
        c.append(term)
        voc.append(term)
    dict.append(c)  
    e.append(voc)  
    counter=0
    for z in final_tokens:
      if z in p_ind:
          if docid in p_ind[z][1]:
            p_ind[z][1][docid].append(counter)
          else:
            p_ind[z][0]=p_ind[z][0]+1
            p_ind[z][1][docid]=[counter]
            counter+=1
      else:
        p_ind[z]=[]
        p_ind[z].append(1)
        p_ind[z].append({})
        p_ind[z][1][docid]=[counter]
        counter=counter+1
    docid+=1
# Out:
# 100%|██████████| 1133/1133 [00:39<00:00, 28.35it/s]

# %%
voc=list(set(voc))

# %%
counter=0
list_pos={}
for i in dict:
  counter+=1
  for x in range(1):
    print("")
  for j in i:
    if j in list_pos:
      list_pos[j].append(counter)
      for x in range(1):
        print("")
    else:
      list_pos[j]=[counter]

# %%
import math

# %%
idf={}                           
for i in tqdm(range(len(voc))):
  for x in range(1):
    print("")
  a=len(list_pos[voc[i]])
  b=len(dict)
  idf[voc[i]]=math.log((b/a+1),10)
# Out:
# 100%|██████████| 60765/60765 [00:00<00:00, 554902.86it/s]

# %%
idf
# Out:
# {'catacomb': 3.0546130545568873,
#  'crowed': 2.75396586586516,
#  'strarted': 3.0546130545568873,
#  'wavering': 2.4537004733597723,
#  'fabian': 3.0546130545568873,
#  'opposed': 1.6831221172401434,
#  'braincells': 3.0546130545568873,
#  'psg': 3.0546130545568873,
#  'ished': 2.75396586586516,
#  'occident': 2.75396586586516,
#  'conasse': 2.75396586586516,
#  'bissett': 3.0546130545568873,
#  'vive': 2.75396586586516,
#  'kb': 2.4537004733597723,
#  'malaise': 3.0546130545568873,
#  'broach': 2.75396586586516,
#  'lob': 2.4537004733597723,
#  'rogerians': 3.0546130545568873,
#  'simp': 3.0546130545568873,
#  'grasping': 2.2783724736954567,
#  'emmerich': 3.0546130545568873,
#  'issidents': 2.5782570766553374,
#  'fevent': 3.0546130545568873,
#  'descarada': 3.0546130545568873,
#  'blazing': 2.154195657426271,
#  'mucilage': 3.0546130545568873,
#  'qbe': 3.0546130545568873,
#  'birney': 2.75396586586516,
#  'nad': 2.4537004733597723,
#  'brascia': 3.0546130545568873,
#  'birthrate': 3.0546130545568873,
#  'alphabetize': 3.0546130545568873,
#  'succumbed': 2.5782570766553374,
#  'solovyez': 3.0546130545568873,
#  'rejectness': 3.0546130545568873,
#  'oversold': 3.0546130545568873,
#  'tarleton': 3.0546130545568873,
#  'neuro': 3.0546130545568873,
#  'nilbogs': 3.0546130545568873,
#  'adieu': 3.0546130545568873,
#  'tyrannosaurus': 2.75396586586516,
#  'ucbvax': 2.0580462303952816,
#  'materialized': 2.3571722577230334,
#  'bunion': 3.0546130545568873,
#  'fear': 0.9642664641527716,
#  'favorite': 0.895790748250444,
#  'rotten': 1.6657685507193798,
#  'morphodites': 3.0546130545568873,
#  'diffcult': 3.0546130545568873,
#  'sscnet': 3.0546130545568873,
#  'smilell': 3.0546130545568873,
#  'wasteful': 2.211806811322216,
#  'florescent': 2.5782570766553374,
#  'cree': 3.0546130545568873,
#  'arrowroot': 3.0546130545568873,
#  'guise': 2.154195657426271,
#  'vaccuum': 3.0546130545568873,
#  'stateliner': 3.0546130545568873,
#  'seame': 3.0546130545568873,
#  'mongolia': 2.5782570766553374,
#  '59f': 3.0546130545568873,
#  'huxley': 3.0546130545568873,
#  'piloted': 3.0546130545568873,
#  'yupa': 3.0546130545568873,
#  'dapper': 3.0546130545568873,
#  'heightened': 2.2783724736954567,
#  '_l': 3.0546130545568873,
#  'tae': 3.0546130545568873,
#  'irrevocable': 3.0546130545568873,
#  'liblick': 3.0546130545568873,
#  'scottsdale': 3.0546130545568873,
#  'malda': 3.0546130545568873,
#  'drangon': 3.0546130545568873,
#  'siezed': 2.75396586586516,
#  'morrissa': 3.0546130545568873,
#  'pube': 3.0546130545568873,
#  'dudeness': 3.0546130545568873,
#  'bringest': 3.0546130545568873,
#  'wilmut': 3.0546130545568873,
#  'delancie': 2.75396586586516,
#  'mil': 2.103423594470504,
#  'postpostscriptum': 3.0546130545568873,
#  'opera': 1.5233747984261048,
#  'included': 1.1243482613549958,
#  'nonce': 3.0546130545568873,
#  'sparge': 2.75396586586516,
#  '_the_princess_bride_': 3.0546130545568873,
#  'dblatttance': 3.0546130545568873,
#  'bimbill': 3.0546130545568873,
#  '8f03': 2.75396586586516,
#  'ondo': 3.0546130545568873,
#  'oeuvre': 2.2783724736954567,
#  'shaw': 1.6657685507193798,
#  'radiesthesia': 3.0546130545568873,
#  'convertables': 3.0546130545568873,
#  'reflog': 3.0546130545568873,
#  'dpa': 3.0546130545568873,
#  'doris': 2.4537004733597723,
#  'dbrod': 3.0546130545568873,
#  'vally': 2.75396586586516,
#  'jeane': 2.75396586586516,
#  'append': 2.4537004733597723,
#  'working': 0.8293854148054928,
#  'hemorrhaging': 3.0546130545568873,
#  'speaker': 1.4778630046555723,
#  'dior': 3.0546130545568873,
#  'insubstantial': 2.75396586586516,
#  'influen': 3.0546130545568873,
#  'longmans': 3.0546130545568873,
#  'parboyle': 3.0546130545568873,
#  '5r': 3.0546130545568873,
#  'nwonknu': 3.0546130545568873,
#  'huntin': 2.4537004733597723,
#  'mahem': 3.0546130545568873,
#  'flatt': 3.0546130545568873,
#  'flinner': 3.0546130545568873,
#  'fangled': 3.0546130545568873,
#  'geule': 2.75396586586516,
#  'bimattress': 3.0546130545568873,
#  'written': 0.8275128652131439,
#  'intensely': 2.0170333392987803,
#  'ofs': 2.75396586586516,
#  'comanche': 3.0546130545568873,
#  'tragically': 2.4537004733597723,
#  'understandingly': 3.0546130545568873,
#  'fondling': 2.5782570766553374,
#  'ebeneezer': 2.5782570766553374,
#  'xxxv': 3.0546130545568873,
#  'frontera': 3.0546130545568873,
#  'brokaw': 3.0546130545568873,
#  'cah': 2.75396586586516,
#  'rehearsed': 2.4537004733597723,
#  'flakey': 3.0546130545568873,
#  'uqcspe': 2.75396586586516,
#  'application': 1.3740147402919114,
#  'prospective': 2.0170333392987803,
#  'photojournalism': 3.0546130545568873,
#  'voess': 3.0546130545568873,
#  'inacomp': 3.0546130545568873,
#  'addis': 3.0546130545568873,
#  'puramidis': 3.0546130545568873,
#  'interrupt': 1.782698878134364,
#  'unemployment': 1.7201593034059568,
#  '9qbg3xiu209b9': 3.0546130545568873,
#  'l1ke': 3.0546130545568873,
#  'opcode': 3.0546130545568873,
#  'pastille': 3.0546130545568873,
#  'broussellet': 3.0546130545568873,
#  'ltu': 3.0546130545568873,
#  'postkanser': 3.0546130545568873,
#  'femmes': 2.5782570766553374,
#  'hl': 3.0546130545568873,
#  'barney': 1.7201593034059568,
#  'breathy': 2.5782570766553374,
#  'simisweet': 3.0546130545568873,
#  'unb': 3.0546130545568873,
#  'carefree': 2.5782570766553374,
#  'undigested': 3.0546130545568873,
#  'light': 0.6908069021853281,
#  'impetuous': 3.0546130545568873,
#  'vasquez': 3.0546130545568873,
#  'falken': 3.0546130545568873,
#  'outburst': 2.75396586586516,
#  'hasl': 3.0546130545568873,
#  'ouch': 2.103423594470504,
#  'recruitment': 2.5782570766553374,
#  'falafel': 3.0546130545568873,
#  'garnish': 1.8302489189753377,
#  'praying': 2.2783724736954567,
#  'gounders': 3.0546130545568873,
#  'petty': 1.7012299980669172,
#  'impediment': 2.5782570766553374,
#  'darker': 2.0170333392987803,
#  'mtbr': 3.0546130545568873,
#  'bauhaus': 2.5782570766553374,
#  'slime': 1.7201593034059568,
#  'convict': 1.9796242406282818,
#  'agnor': 3.0546130545568873,
#  'rjb': 3.0546130545568873,
#  'thish': 2.75396586586516,
#  'moriarty': 2.5782570766553374,
#  'tek': 2.2783724736954567,
#  'esthetic': 3.0546130545568873,
#  'intrinsic': 2.2783724736954567,
#  'corainder': 3.0546130545568873,
#  'functional': 1.8302489189753377,
#  'secret': 0.9785820647142505,
#  'tensest': 3.0546130545568873,
#  'absurdist': 2.75396586586516,
#  'brainstorming': 3.0546130545568873,
#  'exclaims': 2.4537004733597723,
#  'dodging': 2.5782570766553374,
#  'deejays': 3.0546130545568873,
#  'becoming': 1.2410553769294654,
#  'shapiro': 2.5782570766553374,
#  'monging': 3.0546130545568873,
#  'mathemagic': 3.0546130545568873,
#  'csr': 3.0546130545568873,
#  'qmc': 3.0546130545568873,
#  'ravenna': 3.0546130545568873,
#  'amateurishly': 2.75396586586516,
#  'pleasanton': 3.0546130545568873,
#  'colloq': 3.0546130545568873,
#  'marasco': 3.0546130545568873,
#  'governed': 2.5782570766553374,
#  'pinnacl': 3.0546130545568873,
#  'unwanted': 1.8302489189753377,
#  'iscsvax': 3.0546130545568873,
#  'impropriety': 2.5782570766553374,
#  'nay': 2.103423594470504,
#  'backest': 3.0546130545568873,
#  'advertizer': 3.0546130545568873,
#  'atc': 2.75396586586516,
#  'repress': 3.0546130545568873,
#  'newky': 3.0546130545568873,
#  'professing': 3.0546130545568873,
#  'receivable': 3.0546130545568873,
#  'intensification': 3.0546130545568873,
#  'fulton': 2.4537004733597723,
#  'npyle': 3.0546130545568873,
#  'retrieve': 1.7607993116307175,
#  'hilde': 3.0546130545568873,
#  'hugevania': 3.0546130545568873,
#  'knox': 2.5782570766553374,
#  'straining': 2.211806811322216,
#  'dorm': 1.7607993116307175,
#  '1968_': 3.0546130545568873,
#  'inaccuracy': 3.0546130545568873,
#  'agonised': 3.0546130545568873,
#  'dave': 1.1707624255506142,
#  'withdrawl': 2.75396586586516,
#  'monte': 1.9134353822230294,
#  'dawn': 1.6028081301553556,
#  'gnaws': 2.75396586586516,
#  'balmoral': 3.0546130545568873,
#  'reeboks': 3.0546130545568873,
#  'lovely': 1.3910086602379275,
#  'promissory': 3.0546130545568873,
#  'westridge': 2.75396586586516,
#  'prosecuted': 2.3571722577230334,
#  'triptytch': 3.0546130545568873,
#  'unplanned': 2.5782570766553374,
#  'toni': 1.9134353822230294,
#  'accepts': 1.85620004603236,
#  'occosations': 3.0546130545568873,
#  'scorch': 2.5782570766553374,
#  '_organize': 3.0546130545568873,
#  'vegged': 3.0546130545568873,
#  'custard': 2.211806811322216,
#  'memphis': 2.3571722577230334,
#  'motionless': 2.211806811322216,
#  'byline': 2.75396586586516,
#  'sodom': 3.0546130545568873,
#  'noticeable': 2.154195657426271,
#  'endorphin': 2.5782570766553374,
#  'intimidates': 2.75396586586516,
#  'heritage': 2.211806811322216,
#  'detabooization': 3.0546130545568873,
#  'rajiv': 2.5782570766553374,
#  'dadicus': 3.0546130545568873,
#  'saute': 1.9452412653245341,
#  'withthe': 3.0546130545568873,
#  'recognizeable': 3.0546130545568873,
#  'removlarynx': 3.0546130545568873,
#  'formatter': 2.75396586586516,
#  'russe': 3.0546130545568873,
#  'scener': 3.0546130545568873,
#  'physiological': 2.211806811322216,
#  'cenobite': 3.0546130545568873,
#  'large': 0.6017726645018,
#  'espanola': 2.75396586586516,
#  'dasz': 3.0546130545568873,
#  'kilobyte': 2.5782570766553374,
#  'terrifyingly': 3.0546130545568873,
#  'receptable': 3.0546130545568873,
#  'bury': 1.649110087992778,
#  'short': 0.7428821714372729,
#  'convertible': 2.211806811322216,
#  'arlene': 3.0546130545568873,
#  'spellman': 3.0546130545568873,
#  'cyberlink': 3.0546130545568873,
#  'mentioned': 1.0990319772388213,
#  'bimbotch': 3.0546130545568873,
#  'rorke': 3.0546130545568873,
#  'tomei': 2.75396586586516,
#  'dint': 3.0546130545568873,
#  'congressional': 2.4537004733597723,
#  'temperance': 2.4537004733597723,
#  'beating': 1.4778630046555723,
#  'barnacle': 3.0546130545568873,
#  'imaginings': 3.0546130545568873,
#  'mangy': 2.5782570766553374,
#  'duration': 2.0170333392987803,
#  't3': 2.5782570766553374,
#  'felony': 2.4537004733597723,
#  'electro': 2.75396586586516,
#  'sek': 3.0546130545568873,
#  'quits': 2.154195657426271,
#  'shakti': 3.0546130545568873,
#  'slept': 1.739986514085793,
#  'regressed': 3.0546130545568873,
#  'batanides': 2.5782570766553374,
#  'roughies': 3.0546130545568873,
#  'pkg': 2.0170333392987803,
#  'dunham': 3.0546130545568873,
#  'hack': 1.5115120103945527,
#  'handcuff': 2.154195657426271,
#  'huston': 2.75396586586516,
#  'koreth': 3.0546130545568873,
#  'boetcker': 3.0546130545568873,
#  'sculptor': 2.5782570766553374,
#  'zony': 3.0546130545568873,
#  'lensman': 2.75396586586516,
#  'platform': 1.6176741883963546,
#  'sternum': 2.75396586586516,
#  'nandina': 3.0546130545568873,
#  'letting': 1.4672380207875668,
#  'nf': 2.75396586586516,
#  'medak': 2.5782570766553374,
#  'hotton': 3.0546130545568873,
#  'nepeta': 2.5782570766553374,
#  'sproing': 3.0546130545568873,
#  'metalic': 3.0546130545568873,
#  'surge': 2.154195657426271,
#  'quarterly_': 3.0546130545568873,
#  'repo': 2.5782570766553374,
#  'diverter': 3.0546130545568873,
#  'signed______________________': 3.0546130545568873,
#  'magda': 3.0546130545568873,
#  'quackblatt': 3.0546130545568873,
#  'rebottle': 3.0546130545568873,
#  'johnston': 2.3571722577230334,
#  'popwell': 2.75396586586516,
#  'mentally': 1.6831221172401434,
#  'persistently': 3.0546130545568873,
#  'bookish': 3.0546130545568873,
#  'pazu': 3.0546130545568873,
#  'adjunct': 3.0546130545568873,
#  'rediculous': 2.4537004733597723,
#  'tenure': 2.5782570766553374,
#  'encoutneres': 3.0546130545568873,
#  'treadwell': 3.0546130545568873,
#  'lsplorkting': 3.0546130545568873,
#  'ucsb': 2.5782570766553374,
#  'cubicle': 2.2783724736954567,
#  'ndt': 3.0546130545568873,
#  'ruby': 2.0580462303952816,
#  'nctl': 3.0546130545568873,
#  'quality': 1.0603480260117801,
#  'zot': 3.0546130545568873,
#  'wearer': 2.211806811322216,
#  'giambalvo': 2.3571722577230334,
#  'pinpointed': 3.0546130545568873,
#  'knecht': 3.0546130545568873,
#  '700k': 3.0546130545568873,
#  'asiatica': 3.0546130545568873,
#  'physrev': 3.0546130545568873,
#  'villians': 3.0546130545568873,
#  'chas': 3.0546130545568873,
#  'santraginus': 3.0546130545568873,
#  'walkway': 2.211806811322216,
#  'strengthened': 2.5782570766553374,
#  'sax': 2.5782570766553374,
#  'maneater': 2.3571722577230334,
#  '_button': 3.0546130545568873,
#  'turkle': 3.0546130545568873,
#  'spotting': 2.75396586586516,
#  'drug': 0.9785820647142505,
#  'mand': 3.0546130545568873,
#  'brittany': 2.75396586586516,
#  'proprietor': 2.4537004733597723,
#  'toledo': 2.4537004733597723,
#  'replete': 2.75396586586516,
#  'underground': 1.3577150067113235,
#  'cyberwear': 3.0546130545568873,
#  'towelling': 3.0546130545568873,
#  'dickory': 3.0546130545568873,
#  'biopics': 3.0546130545568873,
#  'potentail': 3.0546130545568873,
#  'mayfly': 3.0546130545568873,
#  'substantial': 2.154195657426271,
#  'quaalude': 3.0546130545568873,
#  'explore': 1.6657685507193798,
#  'unvoist': 3.0546130545568873,
#  'underestimate': 2.3571722577230334,
#  'inavders': 3.0546130545568873,
#  'bunny': 1.633094225067931,
#  'mesages': 3.0546130545568873,
#  'policeman': 1.739986514085793,
#  'mannerism': 2.75396586586516,
#  'h_': 3.0546130545568873,
#  'buddah': 3.0546130545568873,
#  'enn': 3.0546130545568873,
#  'elemetns': 3.0546130545568873,
#  'hossman': 3.0546130545568873,
#  'rasins': 3.0546130545568873,
#  'wimpee': 3.0546130545568873,
#  'wrot': 3.0546130545568873,
#  'cheap': 1.1072806498468857,
#  'merriwether': 3.0546130545568873,
#  'minnetonka': 3.0546130545568873,
#  'ominous': 2.0170333392987803,
#  'wray': 3.0546130545568873,
#  'purgative': 3.0546130545568873,
#  'collapsed': 1.9452412653245341,
#  'ginch': 3.0546130545568873,
#  'sensitivity': 2.3571722577230334,
#  'relised': 2.75396586586516,
#  'read': 0.6768449581128604,
#  'csl': 2.75396586586516,
#  'warhawk': 3.0546130545568873,
#  'consignee': 3.0546130545568873,
#  'score': 1.382421396516723,
#  'suprising': 2.4537004733597723,
#  'wyner': 2.5782570766553374,
#  'wriggled': 2.75396586586516,
#  'navarro': 3.0546130545568873,
#  'receptione': 3.0546130545568873,
#  'speakman': 3.0546130545568873,
#  'popped': 1.782698878134364,
#  'trofimov': 3.0546130545568873,
#  'frying': 1.7201593034059568,
#  'mtv': 1.6831221172401434,
#  'hitman': 2.4537004733597723,
#  'propostion': 3.0546130545568873,
#  'lustily': 3.0546130545568873,
#  '_bob_': 3.0546130545568873,
#  'preheat': 1.7607993116307175,
#  'freighting': 3.0546130545568873,
#  'brasso': 3.0546130545568873,
#  'musky': 2.75396586586516,
#  'transmute': 3.0546130545568873,
#  'ritch': 2.3571722577230334,
#  'kiger': 2.75396586586516,
#  'cindy': 2.103423594470504,
#  'spycis': 3.0546130545568873,
#  'arranger': 3.0546130545568873,
#  'lotsa': 3.0546130545568873,
#  'frontier': 1.8058028185264856,
#  'derby': 2.5782570766553374,
#  'heretofore': 2.4537004733597723,
#  'instructing': 3.0546130545568873,
#  'fielek': 3.0546130545568873,
#  'hieght': 2.75396586586516,
#  'identically': 3.0546130545568873,
#  'gutting': 2.75396586586516,
#  'boopsie': 3.0546130545568873,
#  'hissed': 2.75396586586516,
#  'rapport': 3.0546130545568873,
#  'confer': 2.75396586586516,
#  'pce': 3.0546130545568873,
#  'maven': 2.5782570766553374,
#  'semel': 3.0546130545568873,
#  'houseguest': 2.5782570766553374,
#  'romolo': 3.0546130545568873,
#  'bachh': 3.0546130545568873,
#  'gingerale': 3.0546130545568873,
#  'phaser': 2.2783724736954567,
#  'backround': 3.0546130545568873,
#  '______42': 3.0546130545568873,
#  'superfine': 2.3571722577230334,
#  'pomposity': 3.0546130545568873,
#  'rerecording': 3.0546130545568873,
#  'fslic': 3.0546130545568873,
#  'hysterical': 2.154195657426271,
#  'unties': 2.75396586586516,
#  '3m': 2.2783724736954567,
#  'astringent': 2.3571722577230334,
#  'yawara': 2.4537004733597723,
#  'bibliolater': 3.0546130545568873,
#  'barfly': 2.5782570766553374,
#  'dahd': 3.0546130545568873,
#  'themeselves': 3.0546130545568873,
#  'screwdriver': 1.8302489189753377,
#  'accours': 3.0546130545568873,
#  'herblock': 3.0546130545568873,
#  'nutient': 3.0546130545568873,
#  'tenfold': 3.0546130545568873,
#  'sur': 2.211806811322216,
#  'keir': 3.0546130545568873,
#  'heatbeat': 3.0546130545568873,
#  'apricot': 1.9796242406282818,
#  'spurt': 2.3571722577230334,
#  'struggling': 1.7607993116307175,
#  'wurley': 3.0546130545568873,
#  'uva': 2.75396586586516,
#  'othel': 3.0546130545568873,
#  'kincaid': 2.3571722577230334,
#  'astroturf': 2.75396586586516,
#  'hanauer': 3.0546130545568873,
#  'comacocoon': 3.0546130545568873,
#  'wisecracking': 3.0546130545568873,
#  'equivilant': 3.0546130545568873,
#  'disproving': 3.0546130545568873,
#  'nat': 2.2783724736954567,
#  'fulfillment': 2.75396586586516,
#  'tamale': 3.0546130545568873,
#  '_asia': 3.0546130545568873,
#  'bacteria': 1.7012299980669172,
#  'thx': 3.0546130545568873,
#  'gastrically': 3.0546130545568873,
#  'timelord': 2.75396586586516,
#  'frumpy': 3.0546130545568873,
#  'breathed': 2.154195657426271,
#  'redubbed': 3.0546130545568873,
#  'acre': 1.8302489189753377,
#  'bimbug': 3.0546130545568873,
#  'fiftieth': 3.0546130545568873,
#  'yesterday': 1.4672380207875668,
#  'home': 0.6141204166939963,
#  'insanity': 1.7201593034059568,
#  'rightfully': 2.5782570766553374,
#  'vey': 3.0546130545568873,
#  'jan': 1.2655434614104368,
#  'mdm': 3.0546130545568873,
#  'camouflage': 2.75396586586516,
#  'siftedicingsugar': 3.0546130545568873,
#  'shriner': 2.5782570766553374,
#  'gepme': 3.0546130545568873,
#  'quin': 3.0546130545568873,
#  'podiatrist': 2.75396586586516,
#  '_____': 1.6176741883963546,
#  'loompas': 3.0546130545568873,
#  'pbx': 2.4537004733597723,
#  'leo': 1.649110087992778,
#  'cloudbuster': 3.0546130545568873,
#  'clemens': 2.5782570766553374,
#  'hiken': 2.75396586586516,
#  'aesthetic': 2.4537004733597723,
#  'much': 0.519504532782188,
#  'regulatory': 2.103423594470504,
#  'logons': 3.0546130545568873,
#  'paired': 2.5782570766553374,
#  'aykroyd': 2.75396586586516,
#  'prose': 2.0580462303952816,
#  'reno': 2.154195657426271,
#  'cranked': 2.4537004733597723,
#  'dreamt': 2.5782570766553374,
#  '40m': 2.75396586586516,
#  '8ozs': 3.0546130545568873,
#  'writer': 1.111474761516301,
#  'diebus': 3.0546130545568873,
#  'zoebeide': 3.0546130545568873,
#  'addto': 3.0546130545568873,
#  'naoya': 3.0546130545568873,
#  'grit': 2.211806811322216,
#  'fedora': 2.75396586586516,
#  'bravely': 2.2783724736954567,
#  'rancid': 2.5782570766553374,
#  'incoherent': 2.4537004733597723,
#  'teedo': 3.0546130545568873,
#  'reall': 3.0546130545568873,
#  'grocer': 2.4537004733597723,
#  'drawbridge': 3.0546130545568873,
#  'stringing': 2.5782570766553374,
#  'lyson': 3.0546130545568873,
#  'broaden': 3.0546130545568873,
#  'dice': 1.7012299980669172,
#  'seaweed': 2.4537004733597723,
#  'komete': 3.0546130545568873,
#  'falconneil': 3.0546130545568873,
#  'hypmotize': 3.0546130545568873,
#  'devaluation': 3.0546130545568873,
#  'hsx': 3.0546130545568873,
#  'c2': 2.75396586586516,
#  'ataru': 2.75396586586516,
#  'facon': 3.0546130545568873,
#  'ashley': 2.4537004733597723,
#  'unfiltered': 2.75396586586516,
#  'mimicking': 2.75396586586516,
#  'fha': 3.0546130545568873,
#  'spacious': 2.75396586586516,
#  'toting': 2.2783724736954567,
#  'floozy': 2.5782570766553374,
#  'kneecap': 3.0546130545568873,
#  'directing': 1.85620004603236,
#  'berzerker': 3.0546130545568873,
#  'tickled': 2.103423594470504,
#  'kind': 0.7080019110441387,
#  'rippy': 3.0546130545568873,
#  'board': 0.8408546178559536,
#  'domy': 3.0546130545568873,
#  'nmr': 3.0546130545568873,
#  'direction': 1.042439598839731,
#  'rimshot': 2.75396586586516,
#  'winkleman': 3.0546130545568873,
#  'synopsis': 2.103423594470504,
#  'clang': 3.0546130545568873,
#  'owned': 1.4369388661605331,
#  'lounging': 2.75396586586516,
#  'ibmer': 3.0546130545568873,
#  'perpetuity': 2.75396586586516,
#  'ibebg': 3.0546130545568873,
#  'soar': 2.3571722577230334,
#  'genom': 3.0546130545568873,
#  'boarding': 2.0170333392987803,
#  'tinman': 3.0546130545568873,
#  'futher': 2.4537004733597723,
#  'gubarev': 3.0546130545568873,
#  'olkewicz': 2.5782570766553374,
#  'depreciating': 2.75396586586516,
#  'saunter': 2.75396586586516,
#  'controversy': 1.9796242406282818,
#  'dukakis': 2.75396586586516,
#  'b650i': 3.0546130545568873,
#  'gruyere': 3.0546130545568873,
#  'eiss': 3.0546130545568873,
#  'stallion': 2.4537004733597723,
#  'troublesome': 2.4537004733597723,
#  'envious': 2.4537004733597723,
#  'nectarine': 2.75396586586516,
#  'unsing': 3.0546130545568873,
#  'aphid': 3.0546130545568873,
#  'fuzziness': 3.0546130545568873,
#  'undressed': 2.211806811322216,
#  'starfleet': 2.3571722577230334,
#  'newman': 1.9134353822230294,
#  'nocturnal': 2.4537004733597723,
#  'popovich': 3.0546130545568873,
#  'hypersensitivity': 3.0546130545568873,
#  '6lb': 3.0546130545568873,
#  'agre': 3.0546130545568873,
#  'hari': 2.5782570766553374,
#  'crystalize': 2.75396586586516,
#  'slightest': 1.9796242406282818,
#  'noteys': 3.0546130545568873,
#  'cattle': 1.649110087992778,
#  'spicier': 2.75396586586516,
#  'magnolia': 3.0546130545568873,
#  'alleviates': 3.0546130545568873,
#  'remrand': 3.0546130545568873,
#  'merciful': 2.3571722577230334,
#  'nadmenny': 3.0546130545568873,
#  'symantec': 3.0546130545568873,
#  'motherfucker': 2.154195657426271,
#  'macra': 2.75396586586516,
#  'kira': 3.0546130545568873,
#  'kvcc': 3.0546130545568873,
#  'hollered': 2.5782570766553374,
#  'kalen': 3.0546130545568873,
#  'duron': 3.0546130545568873,
#  'jone': 2.75396586586516,
#  'resynchronized': 3.0546130545568873,
#  'sigorsky': 3.0546130545568873,
#  'bility': 3.0546130545568873,
#  'brannish': 3.0546130545568873,
#  'idyllic': 2.4537004733597723,
#  'prestigous': 3.0546130545568873,
#  'blah': 2.2783724736954567,
#  'resorted': 2.75396586586516,
#  'gorabachef': 3.0546130545568873,
#  'agree': 1.2351675873255878,
#  'berkshire': 3.0546130545568873,
#  'apparel': 2.5782570766553374,
#  'debacle': 3.0546130545568873,
#  'angrily': 2.211806811322216,
#  'nellie': 3.0546130545568873,
#  'squarely': 3.0546130545568873,
#  'fright': 2.154195657426271,
#  'team': 1.0753363603303403,
#  'dozen': 1.2351675873255878,
#  'networker': 3.0546130545568873,
#  'tetra': 3.0546130545568873,
#  'embarq': 3.0546130545568873,
#  'preached': 2.75396586586516,
#  'bristol': 2.2783724736954567,
#  'brutalized': 2.75396586586516,
#  'heheh': 2.75396586586516,
#  'ekerli': 3.0546130545568873,
#  'telemarketer': 3.0546130545568873,
#  'bather': 2.75396586586516,
#  'memorial': 1.9452412653245341,
#  'ioof': 3.0546130545568873,
#  'demonstrable': 3.0546130545568873,
#  'fullest': 2.3571722577230334,
#  'kept': 1.0155121661782476,
#  'citric': 2.103423594470504,
#  'kelleye': 3.0546130545568873,
#  'manor': 2.103423594470504,
#  'ryooma': 3.0546130545568873,
#  'pilferer': 3.0546130545568873,
#  'morn': 2.4537004733597723,
#  'conducting': 2.2783724736954567,
#  'hissing': 2.5782570766553374,
#  'menage': 2.5782570766553374,
#  'brack': 3.0546130545568873,
#  'gangbusters': 3.0546130545568873,
#  'averaged': 3.0546130545568873,
#  'voist': 3.0546130545568873,
#  'silent': 1.3054242437620733,
#  'agricultural': 2.2783724736954567,
#  'insertion': 2.75396586586516,
#  'lettuce': 1.9134353822230294,
#  'spectrx': 3.0546130545568873,
#  'bequeath': 2.5782570766553374,
#  'replayed': 2.5782570766553374,
#  'causeway': 3.0546130545568873,
#  'roj': 3.0546130545568873,
#  'tak': 2.3571722577230334,
#  'boggling': 3.0546130545568873,
#  'snotlens': 3.0546130545568873,
#  'flora': 2.3571722577230334,
#  'unpleasant': 1.7607993116307175,
#  'bona': 2.75396586586516,
#  'lamune': 3.0546130545568873,
#  'leeds': 3.0546130545568873,
#  'szurek': 3.0546130545568873,
#  'trophy': 2.154195657426271,
#  'allotted': 2.75396586586516,
#  'riiiiiiiiing': 3.0546130545568873,
#  'lil': 2.4537004733597723,
#  'peterc': 3.0546130545568873,
#  'perfume': 1.8838506290062733,
#  'fishbone': 2.5782570766553374,
#  'gilgalad': 3.0546130545568873,
#  'meoderate': 3.0546130545568873,
#  'chaotic': 1.8838506290062733,
#  'bacardi': 2.4537004733597723,
#  'hatting': 3.0546130545568873,
#  'waken': 3.0546130545568873,
#  'mulligan': 2.3571722577230334,
#  'galtiari': 3.0546130545568873,
#  'dalkon': 3.0546130545568873,
#  'vast': 1.4467885762098545,
#  'reinvent': 2.75396586586516,
#  'constrictor': 2.2783724736954567,
#  'civilly': 3.0546130545568873,
#  'syzygy': 3.0546130545568873,
#  'townes': 2.75396586586516,
#  'dodged': 2.3571722577230334,
#  'equaled': 3.0546130545568873,
#  'terkuhle': 2.5782570766553374,
#  'microwaveable': 3.0546130545568873,
#  'seeping': 3.0546130545568873,
#  'hastar': 3.0546130545568873,
#  'milhous': 3.0546130545568873,
#  'whaddya': 2.2783724736954567,
#  'leah': 2.5782570766553374,
#  'cripple': 2.5782570766553374,
#  'interface': 1.649110087992778,
#  'rhubella': 3.0546130545568873,
#  'bravest': 3.0546130545568873,
#  'ducki': 3.0546130545568873,
#  'turtiainen': 3.0546130545568873,
#  'hindu': 2.2783724736954567,
#  'byusing': 3.0546130545568873,
#  'towed': 3.0546130545568873,
#  'gazzette': 3.0546130545568873,
#  'cajolery': 3.0546130545568873,
#  '__constantly': 2.75396586586516,
#  'heterotic': 3.0546130545568873,
#  'scoff': 2.2783724736954567,
#  'webserver': 3.0546130545568873,
#  'jugganought': 3.0546130545568873,
#  'cylindrical': 2.2783724736954567,
#  'insode': 3.0546130545568873,
#  'bfmny0': 3.0546130545568873,
#  'unprotected': 2.3571722577230334,
#  'lefran': 3.0546130545568873,
#  'trounced': 3.0546130545568873,
#  'societe': 3.0546130545568873,
#  'flo': 2.75396586586516,
#  'saddam': 2.103423594470504,
#  'kewms': 3.0546130545568873,
#  'wysiwyg': 3.0546130545568873,
#  'rotor': 2.5782570766553374,
#  'hehe': 2.2783724736954567,
#  'spellos': 3.0546130545568873,
#  'bodacious': 3.0546130545568873,
#  'trafficker': 2.75396586586516,
#  '40mno': 3.0546130545568873,
#  'bullitt': 3.0546130545568873,
#  'derails': 3.0546130545568873,
#  'claus': 1.8058028185264856,
#  'enrollment': 3.0546130545568873,
#  'documented': 1.782698878134364,
#  'peep': 2.211806811322216,
#  'polarized': 3.0546130545568873,
#  'scrambled': 2.0580462303952816,
#  'intrusive': 3.0546130545568873,
#  'quiqley': 3.0546130545568873,
#  'volkswagon': 2.4537004733597723,
#  'dadoscope': 3.0546130545568873,
#  'infrequently': 2.4537004733597723,
#  'readf': 3.0546130545568873,
#  'gestation': 2.75396586586516,
#  'contends': 3.0546130545568873,
#  'szebra': 3.0546130545568873,
#  'hysterectomy': 3.0546130545568873,
#  'consul': 2.75396586586516,
#  'pandering': 3.0546130545568873,
#  'attorney': 1.633094225067931,
#  'cockle': 3.0546130545568873,
#  'somber': 2.5782570766553374,
#  'ish': 2.0580462303952816,
#  'madwoman': 2.5782570766553374,
#  'inveniendum': 3.0546130545568873,
#  '_midnite': 3.0546130545568873,
#  'html': 2.0580462303952816,
#  'luncheon': 2.75396586586516,
#  'fascinating': 1.8058028185264856,
#  'rake': 2.211806811322216,
#  'foliage': 2.5782570766553374,
#  '40mrequesting': 3.0546130545568873,
#  'notoriously': 2.75396586586516,
#  'friggin': 3.0546130545568873,
#  'unwholesomely': 3.0546130545568873,
#  'attract': 1.5611759470421318,
#  'newbury': 2.75396586586516,
#  'melon': 2.0580462303952816,
#  'recommend': 1.382421396516723,
#  'rcj': 3.0546130545568873,
#  'grantham': 3.0546130545568873,
#  'herschel': 3.0546130545568873,
#  'twinks': 3.0546130545568873,
#  'misappropriated': 3.0546130545568873,
#  'karlstad': 3.0546130545568873,
#  'cutsy': 3.0546130545568873,
#  'requahred': 3.0546130545568873,
#  'gunboat': 3.0546130545568873,
#  'curtailed': 2.75396586586516,
#  'ap': 2.103423594470504,
#  'dimple': 2.75396586586516,
#  'mar': 1.3054242437620733,
#  'plight': 2.211806811322216,
#  'illuminati': 2.5782570766553374,
#  'auxilliary': 3.0546130545568873,
#  'mister': 1.7201593034059568,
#  'toon': 2.0580462303952816,
#  'rumpus': 2.5782570766553374,
#  'steinway': 3.0546130545568873,
#  'fet': 2.75396586586516,
#  'gaw': 3.0546130545568873,
#  'sputter': 3.0546130545568873,
#  'mastiff': 3.0546130545568873,
#  'baiseuse': 2.75396586586516,
#  'bazd': 3.0546130545568873,
#  'caper': 2.0580462303952816,
#  'einar': 3.0546130545568873,
#  'villus': 3.0546130545568873,
#  'icon': 2.0170333392987803,
#  'cocked': 2.5782570766553374,
#  'darke': 3.0546130545568873,
#  'ballet': 2.0170333392987803,
#  'unchecked': 2.5782570766553374,
#  'electromagnetism': 3.0546130545568873,
#  'inscrutably': 3.0546130545568873,
#  'transmarginal': 3.0546130545568873,
#  'gonorrhoea': 3.0546130545568873,
#  'cpd': 3.0546130545568873,
#  'bedtime': 2.4537004733597723,
#  'harpo': 2.75396586586516,
#  'devoe': 2.5782570766553374,
#  'keen': 2.211806811322216,
#  'lopez': 2.75396586586516,
#  'colonel': 1.6176741883963546,
#  'preversions': 3.0546130545568873,
#  'hungry': 1.3657815262889645,
#  'hinted': 2.75396586586516,
#  'infanticide': 2.75396586586516,
#  'unsticky': 3.0546130545568873,
#  'minoru': 3.0546130545568873,
#  'xdr': 3.0546130545568873,
#  'iq': 1.8302489189753377,
#  'dormant': 2.211806811322216,
#  'supported': 1.8302489189753377,
#  'divest': 3.0546130545568873,
#  'geddes': 3.0546130545568873,
#  'concernes': 3.0546130545568873,
#  'henceforth': 2.5782570766553374,
#  'aplets': 2.75396586586516,
#  'postmarked': 3.0546130545568873,
#  'monthly': 1.6831221172401434,
#  'camra': 3.0546130545568873,
#  'quarterdeck': 3.0546130545568873,
#  'artery': 1.9796242406282818,
#  'chandelier': 2.2783724736954567,
#  'packet': 1.4999841376791665,
#  'retrine': 3.0546130545568873,
#  'resist': 1.7012299980669172,
#  'continuing': 1.7012299980669172,
#  'worded': 2.75396586586516,
#  'ezines': 3.0546130545568873,
#  'chubbier': 3.0546130545568873,
#  'imo': 3.0546130545568873,
#  'southland': 3.0546130545568873,
#  'seeming': 2.211806811322216,
#  'rothesay': 3.0546130545568873,
#  'medley': 2.75396586586516,
#  'bimistake': 3.0546130545568873,
#  'chanted': 2.4537004733597723,
#  'mart': 1.6657685507193798,
#  'accuse': 2.0580462303952816,
#  'blumenfeld': 2.5782570766553374,
#  'revoir': 3.0546130545568873,
#  'atrillo': 3.0546130545568873,
#  'ee7': 3.0546130545568873,
#  'dortmunder': 3.0546130545568873,
#  'photoshop': 3.0546130545568873,
#  'catalyzes': 2.4537004733597723,
#  'enterprising': 2.5782570766553374,
#  'karloff': 2.75396586586516,
#  'closest': 1.6028081301553556,
#  'emphasis': 1.7607993116307175,
#  'fermentation': 1.85620004603236,
#  'armored': 2.5782570766553374,
#  'sarder': 3.0546130545568873,
#  'katch': 3.0546130545568873,
#  'inated': 3.0546130545568873,
#  'secretarial': 3.0546130545568873,
#  'slimer': 2.75396586586516,
#  '01hgiy7smhsg9oeset': 3.0546130545568873,
#  'unintentionally': 2.75396586586516,
#  'loren': 3.0546130545568873,
#  'seniority': 3.0546130545568873,
#  'mintest': 3.0546130545568873,
#  'stingy': 3.0546130545568873,
#  'gerrold': 2.2783724736954567,
#  'pheds': 2.75396586586516,
#  'yardarm': 3.0546130545568873,
#  'pained': 2.75396586586516,
#  'schopenhauer': 3.0546130545568873,
#  'bodysculpt': 3.0546130545568873,
#  'fredericton': 3.0546130545568873,
#  'temptation': 1.649110087992778,
#  'anwar': 3.0546130545568873,
#  'swissair': 3.0546130545568873,
#  'maryknoll': 3.0546130545568873,
#  'vanilli': 2.3571722577230334,
#  'aurora': 2.2783724736954567,
#  'symonds': 3.0546130545568873,
#  'oejs': 3.0546130545568873,
#  'schoolmate': 3.0546130545568873,
#  'clawing': 2.75396586586516,
#  'mayhill': 3.0546130545568873,
#  'baken': 3.0546130545568873,
#  'preservation': 2.2783724736954567,
#  'pygmy': 2.5782570766553374,
#  '07094_____________': 3.0546130545568873,
#  'minivan': 3.0546130545568873,
#  'strenuous': 2.5782570766553374,
#  'sired': 2.75396586586516,
#  'bimbattle': 3.0546130545568873,
#  'sehx': 2.75396586586516,
#  'pute': 2.75396586586516,
#  'crashpad': 3.0546130545568873,
#  'increasingly': 1.6176741883963546,
#  'bairgs': 3.0546130545568873,
#  'submitted': 1.7012299980669172,
#  'kane': 2.3571722577230334,
#  'wingless': 3.0546130545568873,
#  'border': 1.6028081301553556,
#  'quaxign': 3.0546130545568873,
#  'thynne': 3.0546130545568873,
#  '3x9': 3.0546130545568873,
#  'mctail': 3.0546130545568873,
#  'dilithium': 2.5782570766553374,
#  '500mg': 3.0546130545568873,
#  'diffrent': 2.5782570766553374,
#  'usrtim': 3.0546130545568873,
#  'ach': 2.5782570766553374,
#  'elke': 2.75396586586516,
#  'b8y': 3.0546130545568873,
#  'tinkle': 2.75396586586516,
#  'sharen': 3.0546130545568873,
#  'fateman': 3.0546130545568873,
#  'thunderbird': 2.2783724736954567,
#  'direst': 3.0546130545568873,
#  'hertzler': 2.75396586586516,
#  'beaut': 3.0546130545568873,
#  'bkv1j': 3.0546130545568873,
#  'reducing': 1.782698878134364,
#  'paese': 3.0546130545568873,
#  'humpin': 2.5782570766553374,
#  'reversing': 2.3571722577230334,
#  'welsh': 2.3571722577230334,
#  'georgium': 3.0546130545568873,
#  'limestone': 2.75396586586516,
#  'debby': 2.5782570766553374,
#  'transend': 3.0546130545568873,
#  'cim': 3.0546130545568873,
#  'applelink': 2.5782570766553374,
#  'cookin': 3.0546130545568873,
#  'corley': 3.0546130545568873,
#  '33m4': 3.0546130545568873,
#  'dreamstate': 2.75396586586516,
#  'mantle': 2.5782570766553374,
#  'fuckyou': 3.0546130545568873,
#  'spooned': 3.0546130545568873,
#  'gunga': 3.0546130545568873,
#  'illusion': 1.8058028185264856,
#  'perform': 1.382421396516723,
#  'divorcee': 2.3571722577230334,
#  'fanzine': 2.154195657426271,
#  'fenric': 3.0546130545568873,
#  'mang': 3.0546130545568873,
#  'rolled': 1.3740147402919114,
#  'docile': 3.0546130545568873,
#  'dom': 2.0170333392987803,
#  'gaelic': 2.75396586586516,
#  ...}

# %%
len(idf)
# Out:
# 60765

# %%
import math

# %%
voc=list(set(voc))

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
for x in range(1):
  print("")
tf3={}
for x in range(1):
  print("")
for i in tqdm(voc):
  pair3={}
  for z in range(len(dict)):
    if (z+1) not in list(p_ind[i][1].keys()):
      count=math.log((0+1),10)
    else:
      count=math.log((len(p_ind[i][1][z+1])+1),10)
    pair3[b[z]]=count
  tf3[i]=pair3
for x in range(1):
  print("")
# Out:
# 100%|██████████| 60765/60765 [01:57<00:00, 518.64it/s]

# %%
b=[]
for i in glob.glob(P):
  b.append(os.path.basename(i))

# %%
for x in range(1):
  print("")
tf_idf=[]
for z in tqdm(range(len(dict))):
  s=[]
  for i in voc:
    s.append(tf3[i][b[z]]*idf[i])
    for x in range(1):
      print("")
  tf_idf.append(s)
for x in range(1):
  print("")
# Out:
# 100%|██████████| 1133/1133 [02:07<00:00,  8.90it/s]

# %%
for x in range(1):                                                 #converting into array
  print("")
tf_idf=np.asarray(tf_idf)
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
d=pd.DataFrame(tf_idf,columns=voc)                              #dataframe
for x in range(1):
  print("")

# %%
stop_words = set(stopwords.words('english'));           #query preprocessing
c=[]
f=[]
text=input("Enter your query:")
#Sentence Preprocessing
text=text.lower()   #to convert in to lower case 
text=text.strip()
text = re.sub(r'[^\w\s]', ' ', text)  # To remove puntuation
word_tokens = word_tokenize(text)   # toknization 
final_tokens=[w for w in word_tokens if w not in stop_words] # stopword remove
final_tokens=[ lemmatizer.lemmatize(word) for word in final_tokens]
final_tokens = [x for x in final_tokens if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
final_tokens=set(final_tokens)

#remove stopwords
for word in final_tokens:
  if word not in stopwords.words('english'):
    f.append(word)
for x in f:
  if x not in c:
    c.append(x)
# Out:
# Enter your query:cold water

# %%
for x in range(1):
  print("")
d1=pd.DataFrame(columns=c)
for x in range(1):
  print("")

# %%
for x in range(1):                   #sum and sorting is done 
  print("")
sum_count=0
sort={}
di={}
for x in range(1):
  print("")
for i in c:
  for j in range(len(d)):
    d1.at[j,i]=d.at[j,i]
for i in list(d1.columns):
  sum_count=sum_count+d1[i]
  d1['sum']=sum_count
for i in range(len(d1)):
  di[b[i]]=d1['sum'][i]
  sorted_keys=sorted(di,key=di.get,reverse=True)
for x in range(1):
  print("")
for i in sorted_keys:
  sort[i]=di[i]
for x in range(1):
  print("")

# %%
for x in range(1):
  print("")
z=list(sort.keys())
print(z[0:5])
for x in range(1):
  print("")
# Out:
# ['dym', 'onetoone.hum', 't_zone.jok', 'smurfkil.hum', 'texican.dic']
